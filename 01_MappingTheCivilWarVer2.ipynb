# %% [markdown]
# # Introduction
#
# This lesson is the first of two that will show how to create maps in Python using Folium.
#
# [Folium](https://python-visualization.github.io/folium/) is a wrapper that automates creating Leaflet maps. These maps (like Bokah graphs) are interactive: the user can zoom in and out, pan, etc., to explore the map.
#
# The mapmaker doesn't need to work with HTML, CSS, or JavaScript: everything can be done within the Python ecosystem.
#
# This makes it *much* easier to create a wide variety of different types of maps.
#
# This lesson will show how to use Folium to create maps with points and circles, how to change their size and color, and how to annotate them with popup texts.

# %%
# !pip3 install folium
# !pip3 install xyzservices

from xyzservices import TileProvider

# %%
# import our tool libraries
import pandas as pd
import folium

# %% [markdown]
# According to this [Kaggle notebook](https://www.kaggle.com/code/alexisbcook/exercise-interactive-maps), adding

# %%
def embed_map(m, file_name):
    from IPython.display import IFrame
    m.save(file_name)
    return IFrame(file_name, width='100%', height='500px')

# %% [markdown]
# ## Get the Data
#
# Unlike many of our lessons, this one will draw on historical data, specifically a database of civil war battles.
#
# The data we will be working with is [Jeffry Arnolds'](https://github.com/jrnold/acw_battle_data) [dataset](https://acw-battle-data.readthedocs.io/en/latest/). Arnold's data doesn't include lat/long data, so Karsdorp, Kestemont, and Allen added it as part of their "Narrating with Maps," chapter 7 of their excellent [*Humanities Data Analysis: Case Studies with Python*](https://www.amazon.com/Humanities-Data-Analysis-Studies-Python/dp/0691172366) (Princeton: Princeton University Press, 2021). Their code and data can be found at [Zenodo](https://zenodo.org/record/3563075).
#
# I have taken the data developed as part of this chapter and saved it to my [Github Repo for this class](https://github.com/adamlporter/DataAnalysisClass). We will load the data from that repo.

# %%
df = pd.read_csv('https://raw.githubusercontent.com/adamlporter/DataAnalysisClass/master/cwsac_battle_locations_with_lat_long_tabdelim.csv',
                 sep = '\t',
                 parse_dates=['start_date','end_date'])

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 382 entries, 0 to 381
# Data columns (total 25 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   battle           382 non-null    object
#  1   url              382 non-null    object
#  2   battle_name      382 non-null    object
#  3   other_names      197 non-null    object
#  4   state            382 non-null    object
#  5   locations        382 non-null    object
#  6   campaign         382 non-null    object
#  7   start_date       382 non-null    datetime64[ns]
#  8   end_date         382 non-null    datetime64[ns]
#  9   operation        382 non-null    int64
#  10  assoc_battles    2 non-null      object
#  11  results_text     382 non-null    object
#  12  result           382 non-null    object
#  13  forces_text      381 non-null    object
#  14  strength         59 non-null     float64
#  15  casualties_text  376 non-null    object
#  16  casualties       317 non-null    float64
#  17  description      382 non-null    object
#  18  preservation     372 non-null    object
#  19  significance     382 non-null    object
#  20  strength_mean    270 non-null    float64
#  21  strength_var     270 non-null    float64
#  22  location_name    382 non-null    object
#  23  lat              382 non-null    float64
#  24  lon              382 non-null    float64
# dtypes: datetime64[ns](2), float64(6), int64(1), object(16)
# memory usage: 74.7+ KB

# %% [markdown]
# ## Draw a basic map
#
# Let's start with a quick-and-dirty map.
#
# Folium first requires us to initiate a Map object. We need to specify the center location of the map, the tile set we want to use, and a zoom level.
#
# I generally center my maps on the center of the data. We can calculate this easily by finding the midpoint between the min and max values for lat / lon:
# ```
# center = [ (df['lat'].max() + df['lat'].min())/2,
#              (df['lon'].max() + df['lon'].min())/2]
# ```

# %% [markdown]
# ### Select a basemap
#
# Folium includes a number of [different tile sets](https://xyzservices.readthedocs.io/en/stable/gallery.html) that will provide the basemap, upon which our data will be displayed. The default is `OpenStreetMap` but this doesn't make sense for a Civil War map. So we will use the `OpenTopoMap` map instead.
#
# Finally, we need to specify a `zoom_start` value. This will vary depending on the size of the map.

# %%
provider = TileProvider.from_qms("OpenTopoMap")

center = [ (df['lat'].max() + df['lat'].min())/2,(df['lon'].max() + df['lon'].min())/2]

m = folium.Map(location=center,
               zoom_start = 5)
folium.TileLayer(provider).add_to(m)

m # draw the (blank) map
#embed_map(m,'m1.html')
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_422fa5660bf6f13dc9c6483fc7e8f64e {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_422fa5660bf6f13dc9c6483fc7e8f64e&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_422fa5660bf6f13dc9c6483fc7e8f64e = L.map(
#                 &quot;map_422fa5660bf6f13dc9c6483fc7e8f64e&quot;,
#                 {
#                     center: [36.731948, -93.71588750000001],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 5,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_c4fa48963cec76851a9f581a63a40beb = L.tileLayer(
#                 &quot;Stamen Terrain&quot;,
#                 {&quot;attribution&quot;: &quot;\u003ca href=https://endless-sky.github.io/\u003eEndless Sky\u003c/a\u003e&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#                 tile_layer_c4fa48963cec76851a9f581a63a40beb.addTo(map_422fa5660bf6f13dc9c6483fc7e8f64e);
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# After we have initiated our map object, we can plot our data. Pandas gurus argue against using the `.iterrows()` because it is slow, but most maps use relatively small dataframes, so speed isn't *that* important.
#
# For our first map, we will just iterate over the dataframe and plot battle locations. Folium has a large number of different ways to plot data.
#
# If we use the `.Marker` method and just provide location information (lat/lon coordinates), Folium will create a map with the familiar 'info-sign' icons.

# %%
center = [ (df['lat'].max() + df['lat'].min())/2,(df['lon'].max() + df['lon'].min())/2]
m = folium.Map(location=center,
               zoom_start = 5)
folium.TileLayer(provider).add_to(m)

for idx,row in df.iterrows():
    folium.Marker(location = [row['lat'],row['lon']]
                         ).add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_16096c8efe4156351f72aaeb10f7cea4 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_16096c8efe4156351f72aaeb10f7cea4&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_16096c8efe4156351f72aaeb10f7cea4 = L.map(
#                 &quot;map_16096c8efe4156351f72aaeb10f7cea4&quot;,
#                 {
#                     center: [36.731948, -93.71588750000001],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 5,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_ce202d9ccabf6f892423cb01a4acad58 = L.tileLayer(
#                 &quot;https://stamen-tiles-{s}.a.ssl.fastly.net/terrain/{z}/{x}/{y}.jpg&quot;,
#                 {&quot;attribution&quot;: &quot;Map tiles by \u003ca target=\&quot;_blank\&quot; href=\&quot;http://stamen.com\&quot;\u003eStamen Design\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://creativecommons.org/licenses/by/3.0\&quot;\u003eCC BY 3.0\u003c/a\u003e. Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://creativecommons.org/licenses/by-sa/3.0\&quot;\u003eCC BY SA\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_16096c8efe4156351f72aaeb10f7cea4);
#
#
#             var marker_a83eca83ee6ce3cbddaee8930dcd035b = L.marker(
#                 [34.132644, -86.895744],
#                 {}
#             ).addTo(map_16096c8efe4156351f72aaeb10f7cea4);
#
#
#             var marker_5f7f23ea00017adc91bfadf6d24b7321 = L.marker(
#                 [34.819258, -86.976644],
#                 {}
#             ).addTo(map_16096c8efe4156351f72aaeb10f7cea4);
#
#
#             var marker_6af2bc90d59f02ea2eed7197fd1455fe = L.marker(
#                 [30.669382, -88.202374],
#                 {}
#             ).addTo(map_16096c8efe4156351f72aaeb10f7cea4);
#
#
#             var marker_4b2e62d11def03aa228975c1c40eeb61 = L.marker(
#                 [34.434541, -86.847604],
#                 {}
#             ).addTo(map_16096c8efe4156351f72aaeb10f7cea4);
#
#
#             var marker_ed835e37718a5740064d39bde800d987 = L.marker(
#                 [30.555224, -87.722616],
#                 {}
#             ).addTo(map_16096c8efe4156351f72aaeb10f7cea4);
#
#
#             var marker_7d7d12af0269f523886b758370a8f4de = L.marker(
#                 [30.555224, -87.722616],
#                 {}
#             ).addTo(map_16096c8efe4156351f72aaeb10f7cea4);
#
#
#             var marker_3a174ab652f9718abff92a43540bd40c = L.marker(
#                 [32.283851, -87.111517],
#                 {}
#             ).addTo(map_16096c8efe4156351f72aaeb10f7cea4);
#
#
#             var marker_5bb5e641b71ecc08e279ea0d5b820f45 = L.marker(
#                 [36.35609, -94.256145],
#                 {}
#             ).addTo(map_16096c8efe4156351f72aaeb10f7cea4);
#
#
#             var marker_c20298a5dab9bb3015d437ba09e005bf = L.marker(
#                 [34.301756, -91.348247],
#                 {}
#             ).addTo(map_16096c8efe4156351f72aaeb10f7cea4);
#
#
#             var marker_3ab311d90f8416a0f240e9bb80e22945 = L.marker(
#                 [35.180188, -91.216936],
#                 {}
#             ).addTo(map_16096c8efe4156351f72aaeb10f7cea4);
#
#
#             var marker_656025e2949f116068312605e5d1e720 = L.marker(
#                 [35.97907, -94.21558],
#                 {}
#             ).addTo(map_16096c8efe4156351f72aaeb10f7cea4);
#
#
#             var marker_a6ed6adc9f7074440481e73af224eaec = L.marker(
#                 [35.97907, -94.21558],
#                 {}
#             ).addTo(map_16096c8efe4156351f72aaeb10f7cea4);
#
#
#             var marker_91c365099d2f0eaa18f8290fdb612cbb = L.marker(
#                 [34.301756, -91.348247],
#                 {}
#             ).addTo(map_16096c8efe4156351f72aaeb10f7cea4);
#
#
#             var marker_c7b1d1ac1273f3edc3bdccf7574797ca = L.marker(
#                 [36.378952, -90.417358],
#                 {}
#             ).addTo(map_16096c8efe4156351f72aaeb10f7cea4);
#
#
#             var marker_356dfe810cbcdfaa44583d2a8d997963 = L.marker(
#                 [34.491703, -90.847984],
#                 {}
#             ).addTo(map_16096c8efe4156351f72aaeb10f7cea4);
#
#
#             var marker_2e04a938b8e3f2a77adb8a1d79608159 = L.marker(
#                 [35.202475, -94.290878],
#                 {}
#             ).addTo(map_16096c8efe4156351f72aaeb10f7cea4);
#
#
#             var marker_cfccb7346d08bee56fd413ee28ec8f9f = L.marker(
#                 [34.754519, -92.251272],
#                 {}
#             ).addTo(map_16096c8efe4156351f72aaeb10f7cea4);
#
#
#             var marker_a2db7bd8ba829212058faa5895f8bded = L.marker(
#                 [34.26879, -91.93151],
#                 {}
#             ).addTo(map_16096c8efe4156351f72aaeb10f7cea4);
#
#
#             var marker_5764cf6cc0997d8a20ebf6c45da174a2 = L.marker(
#                 [34.043333, -93.182389],
#                 {}
#             ).addTo(map_16096c8efe4156351f72aaeb10f7cea4)

# %% [markdown]
# ### Change Glyphs and Colors
#
# Rather than having a little white circle, you can specify a different icon for the pin.
# Folium supports bootstrap, so you specify an icon from the [glyph list](https://getbootstrap.com/docs/3.3/components/) to put on the marker.
#
# You can also specify different colors from the [default list](https://python-visualization.github.io/folium/modules.html#Icon):
# ```
# ['red', 'blue', 'green', 'purple', 'orange', 'darkred',
#  'lightred', 'beige', 'darkblue', 'darkgreen', 'cadetblue',
#  'darkpurple', 'white', 'pink', 'lightblue', 'lightgreen',
#  'gray', 'black', 'lightgray']
# ```
#
# To see this, I have created lists of the glyphs (not all of them!) and colors; we will assign them randomly to the different pins:

# %%
import random

m = folium.Map(location=center,
               zoom_start = 5)
folium.TileLayer(provider).add_to(m)

colors = ['red', 'blue', 'green', 'purple', 'orange', 'darkred',
        'lightred', 'beige', 'darkblue', 'darkgreen', 'cadetblue',
        'darkpurple', 'white', 'pink', 'lightblue', 'lightgreen',
        'gray', 'black', 'lightgray']

icons = ['home','flag','time','road','cog','trash','lock','headphones',
         'tag','video','book','tags','tint','question_sign','info-sign',
         'screenshot','exclamation-sign','plane','leaf','fire','gift','ok-sign',
         'certificate','thumbs-up','heart-empty','paperclip']

for idx,row in df.iterrows():
    folium.Marker(location = [row.lat,row.lon],
                icon=folium.Icon(icon = random.choice(icons),
                                 color = random.choice(colors)),
                         ).add_to(m)
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_e24fd4985a13a7961d3b2faab8e48631 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_e24fd4985a13a7961d3b2faab8e48631&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_e24fd4985a13a7961d3b2faab8e48631 = L.map(
#                 &quot;map_e24fd4985a13a7961d3b2faab8e48631&quot;,
#                 {
#                     center: [36.731948, -93.71588750000001],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 5,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_80583a8c52a86532ce126448434a53ef = L.tileLayer(
#                 &quot;https://stamen-tiles-{s}.a.ssl.fastly.net/terrain/{z}/{x}/{y}.jpg&quot;,
#                 {&quot;attribution&quot;: &quot;Map tiles by \u003ca target=\&quot;_blank\&quot; href=\&quot;http://stamen.com\&quot;\u003eStamen Design\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://creativecommons.org/licenses/by/3.0\&quot;\u003eCC BY 3.0\u003c/a\u003e. Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://creativecommons.org/licenses/by-sa/3.0\&quot;\u003eCC BY SA\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_e24fd4985a13a7961d3b2faab8e48631);
#
#
#             var marker_61313cede90798c574f7fd174157e6fd = L.marker(
#                 [34.132644, -86.895744],
#                 {}
#             ).addTo(map_e24fd4985a13a7961d3b2faab8e48631);
#
#
#             var icon_479802504e6dddbc8bfaad91b1202d31 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;leaf&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;lightblue&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_61313cede90798c574f7fd174157e6fd.setIcon(icon_479802504e6dddbc8bfaad91b1202d31);
#
#
#             var marker_c905cf983f863cb20704d381d545fe10 = L.marker(
#                 [34.819258, -86.976644],
#                 {}
#             ).addTo(map_e24fd4985a13a7961d3b2faab8e48631);
#
#
#             var icon_dbfd8da7aa942a90af6a88cf1fe2bec5 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;ok-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;darkblue&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_c905cf983f863cb20704d381d545fe10.setIcon(icon_dbfd8da7aa942a90af6a88cf1fe2bec5);
#
#
#             var marker_141c682f05abbe1eed60c53a495a67ca = L.marker(
#                 [30.669382, -88.202374],
#                 {}
#             ).addTo(map_e24fd4985a13a7961d3b2faab8e48631);
#
#
#             var icon_6a1f4302e8de342819d31fd6d4850189 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;tag&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;darkblue&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_141c682f05abbe1eed60c53a495a67ca.setIcon(icon_6a1f4302e8de342819d31fd6d4850189);
#
#
#             var marker_00c63f22b9ca7a4175a93d93c5673647 = L.marker(
#                 [34.434541, -86.847604],
#                 {}
#             ).addTo(map_e24fd4985a13a7961d3b2faab8e48631);
#
#
#             var icon_20a160bc66151c758b03cede80fbbf45 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;thumbs-up&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;purple&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_00c63f22b9ca7a4175a93d93c5673647.setIcon(icon_20a160bc66151c758b03cede80fbbf45);
#
#
#             var marker_405688c80dd7e4039fec0aa1b9d482ec = L.marker(
#                 [30.555224, -87.722616],
#                 {}
#             ).addTo(map_e24fd4985a13a7961d3b2faab8e48631);
#
#
#             var icon_93eb5416212aefe89f55d550008ded10 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;leaf&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;lightgray&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_405688c80dd7e4039fec0aa1b9d482ec.setIcon(icon_93eb5416212aefe89f55d550008ded10);
#
#
#             var marker_89474d7f16d4d8d06ad359a7d14429a3 = L.marker(
#                 [30.555224, -87.722616],
#                 {}
#             ).addTo(map_e24fd4985a13a7961d3b2faab8e48631);
#
#
#             var icon_fd1a15dc478a750d044fd1cefe876a4f = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;trash&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;lightblue&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_89474d7f16d4

# %% [markdown]
# This map looks silly, which is inappropriate given the seriousness of the map. More Americans died in the Civil War than in any other war in which the US has fought.
#
# Mapmakers should think carefully about the sorts of colors and glyphs that are appropriate for the topic.
#
# Folium allows us to add popup information to the markers by using either the `popup=` or `tooltip=` parameters.
# * `popup=` requires the user to click on the point to see the information
# * `tooltip=` will display the information as the user moves their pointer across the map
#
# We can assign data from the dataframe directly, if it is a string. If the data we want to inclue in the popup is a number or date, we will need to do a little manipulation to turn it into a string. This is straight-forward with [f-string](https://realpython.com/python-f-strings/) formatting.

# %%
m = folium.Map(location=center,
               zoom_start = 5)
folium.TileLayer(provider).add_to(m)

for idx,row in df.iterrows():
  popup_text = f"{row.campaign}\nDate: {row.start_date:%Y-%m-%d}\nCasualities: {row.casualties:,.0f}"

  folium.Marker(location = [row.lat,row.lon],
                icon=folium.Icon(icon='star',color = 'green'),
                popup = popup_text
                         ).add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_7ef3f507d8dfbdd0b897ffb60bb520df {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_7ef3f507d8dfbdd0b897ffb60bb520df&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_7ef3f507d8dfbdd0b897ffb60bb520df = L.map(
#                 &quot;map_7ef3f507d8dfbdd0b897ffb60bb520df&quot;,
#                 {
#                     center: [36.731948, -93.71588750000001],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 5,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_e7f586bbe27647c844d549cbd0940bec = L.tileLayer(
#                 &quot;https://stamen-tiles-{s}.a.ssl.fastly.net/terrain/{z}/{x}/{y}.jpg&quot;,
#                 {&quot;attribution&quot;: &quot;Map tiles by \u003ca target=\&quot;_blank\&quot; href=\&quot;http://stamen.com\&quot;\u003eStamen Design\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://creativecommons.org/licenses/by/3.0\&quot;\u003eCC BY 3.0\u003c/a\u003e. Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://creativecommons.org/licenses/by-sa/3.0\&quot;\u003eCC BY SA\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_7ef3f507d8dfbdd0b897ffb60bb520df);
#
#
#             var marker_b4a55ae192b0c9839508413a3880a46e = L.marker(
#                 [34.132644, -86.895744],
#                 {}
#             ).addTo(map_7ef3f507d8dfbdd0b897ffb60bb520df);
#
#
#             var icon_79c58c85bf6e56b0687fa535a096dedc = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;star&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;green&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_b4a55ae192b0c9839508413a3880a46e.setIcon(icon_79c58c85bf6e56b0687fa535a096dedc);
#
#
#         var popup_ccf1651510ce7944e89eb4cb1d25d074 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_7176bbac7de6d42654f783e2d61da84b = $(`&lt;div id=&quot;html_7176bbac7de6d42654f783e2d61da84b&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Streight&#x27;s Raid in Alabama and Georgia [April 1863] Date: 1863-04-30 Casualities: 88&lt;/div&gt;`)[0];
#                 popup_ccf1651510ce7944e89eb4cb1d25d074.setContent(html_7176bbac7de6d42654f783e2d61da84b);
#
#
#
#         marker_b4a55ae192b0c9839508413a3880a46e.bindPopup(popup_ccf1651510ce7944e89eb4cb1d25d074)
#         ;
#
#
#
#
#             var marker_7721cbacdba96513a7c653e3ade3a011 = L.marker(
#                 [34.819258, -86.976644],
#                 {}
#             ).addTo(map_7ef3f507d8dfbdd0b897ffb60bb520df);
#
#
#             var icon_a05f42056cc08b4ba18e1149b2075701 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;star&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;green&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_7721cbacdba96513a7c653e3ade3a011.setIcon(icon_a05f42056cc08b4ba18e1149b2075701);
#
#
#         var popup_8d60c0748475370cdb9a2fd13199e308 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_42643649d55170b2389c1b88e5b6095c = $(`&lt;div id=&quot;html_42643649d55170b2389c1b88e5b6095c&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Operations in North Alabama [January 1864] Date: 1864-01-26 Casualities: 50&lt;/div&gt;`)[0];
#                 popup_8d60c0748475370cdb9a2fd13199e308.setContent(html_42643649d55170b2389c1b88e5b6095c);
#
#
#
#         marker_7721cbacdba96513a7c653e3ade3a011.bindPopup(popup_8d60c0748475370cdb9a2fd13199e308)
#         ;
#
#
#
#
#             var marker_f7822cca0b65f96191641331d3d6455e = L.marker(
#                 [30.669382, -88.202374],
#                 {}
#             ).addTo(map_7ef3f507d8dfbdd0b897ffb60bb520df);
#
#
#             var icon_f990180cb1f6899b530399e833da01aa = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;star&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;green&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_f7822cca0b65f96191641331d3d6455e.setIcon(icon_f990180cb1f6899b530399e833da01aa);
#
#
#         var popup_b1b9ccacf3be96f5c0afcc98381585fd = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_a95296675d971319172957a45161c8e6 = $(`&lt;div id=&quot;html_a95296675d971319172957a45161c8e6&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Operations in Mobile Bay [August 1864] Date: 1864-08-02 Casualities: 1,822&lt;/div&gt;`)[0];
#                 popup_b1b9ccacf3be96f5c0afcc98381585fd.setContent(html_a95296675d971319172957a45161c8e6);
#
#
#
#         marker_f7822cca

# %% [markdown]
# The F-string formatting gives mapmakers enormous control over the text that appears.
#
# For example, the campaign name includes dates:
# ```
# Sand Creek Campaign [November 1964]
# ```
# But the database includes specific dates. We don't need to specify a temporary variable: the f-string allows us to modify the text in place:
# ```python
# row.campaign.split('[')[0]
# ```
# will split the campaign text string at the opening bracket ("["). This results in two text strings; we select the first one by specifying the first string with the ```[0]``` index.
#
# If we want to boldface the labels for "Date" and "Casualities", we can use the HTML code (```<B>...</B>``` to boldface the text between the tags.
#
# Doing both of these, we can create a new f-string:
#
# ```python
#   popup_text = f"{row.campaign.split('[')[0]}\n<B>Date:</B> {row.start_date:%Y-%m-%d}\n<B>Casualities:</B> {row.casualties:,.0f}"
# ```
# I will redraw the map above with the new popup_text string. I will also change this to a `tool_tip`, so you can see the difference.

# %%
m = folium.Map(location=center, zoom_start = 5)
folium.TileLayer(provider).add_to(m)

for idx,row in df.iterrows():
  popup_text = f"{row.campaign.split('[')[0]}\n<B>Date:</B> {row.start_date:%Y-%m-%d}\n<B>Casualities:</B> {row.casualties:,.0f}"

  folium.Marker(location = [row.lat,row.lon],
                icon=folium.Icon(icon='star',color = 'green'),
                tooltip = popup_text
                         ).add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_fef4c26570c66ab2ca2a59da0ddd3dfc {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_fef4c26570c66ab2ca2a59da0ddd3dfc&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_fef4c26570c66ab2ca2a59da0ddd3dfc = L.map(
#                 &quot;map_fef4c26570c66ab2ca2a59da0ddd3dfc&quot;,
#                 {
#                     center: [36.731948, -93.71588750000001],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 5,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_187114d818f7567399767c6996eb412a = L.tileLayer(
#                 &quot;https://stamen-tiles-{s}.a.ssl.fastly.net/terrain/{z}/{x}/{y}.jpg&quot;,
#                 {&quot;attribution&quot;: &quot;Map tiles by \u003ca target=\&quot;_blank\&quot; href=\&quot;http://stamen.com\&quot;\u003eStamen Design\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://creativecommons.org/licenses/by/3.0\&quot;\u003eCC BY 3.0\u003c/a\u003e. Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://creativecommons.org/licenses/by-sa/3.0\&quot;\u003eCC BY SA\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_fef4c26570c66ab2ca2a59da0ddd3dfc);
#
#
#             var marker_8306ab89be3cedce52bd3382acb9f4e6 = L.marker(
#                 [34.132644, -86.895744],
#                 {}
#             ).addTo(map_fef4c26570c66ab2ca2a59da0ddd3dfc);
#
#
#             var icon_d251bf44b9ef5bbdca352221764508b7 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;star&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;green&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_8306ab89be3cedce52bd3382acb9f4e6.setIcon(icon_d251bf44b9ef5bbdca352221764508b7);
#
#
#             marker_8306ab89be3cedce52bd3382acb9f4e6.bindTooltip(
#                 `&lt;div&gt;
#                      Streight&#x27;s Raid in Alabama and Georgia
# &lt;B&gt;Date:&lt;/B&gt; 1863-04-30
# &lt;B&gt;Casualities:&lt;/B&gt; 88
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_71b40dc0191e2aa56ee4ee2f991aa794 = L.marker(
#                 [34.819258, -86.976644],
#                 {}
#             ).addTo(map_fef4c26570c66ab2ca2a59da0ddd3dfc);
#
#
#             var icon_15b9fff75c17dfb545174e8f8a7b94bc = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;star&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;green&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_71b40dc0191e2aa56ee4ee2f991aa794.setIcon(icon_15b9fff75c17dfb545174e8f8a7b94bc);
#
#
#             marker_71b40dc0191e2aa56ee4ee2f991aa794.bindTooltip(
#                 `&lt;div&gt;
#                      Operations in North Alabama
# &lt;B&gt;Date:&lt;/B&gt; 1864-01-26
# &lt;B&gt;Casualities:&lt;/B&gt; 50
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_cf978c9b6f3610d6113ab73724e71f7a = L.marker(
#                 [30.669382, -88.202374],
#                 {}
#             ).addTo(map_fef4c26570c66ab2ca2a59da0ddd3dfc);
#
#
#             var icon_5376240ce4a64bcd4c8053dd557901cb = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;star&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;green&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_cf978c9b6f3610d6113ab73724e71f7a.setIcon(icon_5376240ce4a64bcd4c8053dd557901cb);
#
#
#             marker_cf978c9b6f3610d6113ab73724e71f7a.bindTooltip(
#                 `&lt;div&gt;
#                      Operations in Mobile Bay
# &lt;B&gt;Date:&lt;/B&gt; 1864-08-02
# &lt;B&gt;Casualities:&lt;/B&gt; 1,822
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_086eeb56557d8cfe2af1577129971f47 = L.marker(
#                 [34.434541, -86.847604],
#                 {}
#             ).addTo(map_fef4c26570c66ab2ca2a59da0ddd3dfc);
#
#
#             var icon_a7654adb89b49ec48522fd6637ee4ba4 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;star&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;green&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_086eeb56557d8cfe2af1577129971f47.setIcon(icon_a7654adb89b49ec48522fd6637ee4ba4);
#
#
#             marker_086eeb56557d8cfe2af1577129971f47.bindTooltip(
#                 `&lt;div&gt;
#                      Franklin-Nashville Campaign
# &lt;B&gt;Date:&lt;/B&gt; 1864-10-26
# &lt;B&gt;Casualities:&lt;/B&gt; 605
#                  &lt;/div&gt;`,

# %% [markdown]
# ## Other Markers
#
# There are situations where the markers used on the above maps will be perfectly adequate. One problem with them is that they are large and tend to overlie each other, making it hard to see some markers, epecially on crowded maps.
#
# Folium has two other markers that work better in this situation: `.Circle()` and `.CircleMarker()`. The first is measured in meters; the second in pixels. If the use the `.Circle()` marker, when we zoom in/out ont he map, the marker will change; if the use `.CircleMarker()` the dot will remain the same size.
#
# These markers have some of the same attributes (color and popup) as the `.Marker()` we used before, but additionally, we can specify
# * `radius` - the size of the circle (in meters or pixels)
# * `fill` - should the circle be filled in or not
# * `fill_opacity` - how opaque should the circle be (this is useful if we have larger circles that might overlie each other)

# %%
m = folium.Map(location=center, zoom_start = 5)
folium.TileLayer(provider).add_to(m)

for idx,row in df.iterrows():
    popup_text = f"{row.battle_name}\nDate: {row.start_date:%Y-%m-%d}\nCasualities: {row.casualties:,.0f}"
    folium.CircleMarker(location = [row.lat,row.lon],
                color = 'red',
                radius = 3,
                fill = True,
                fill_opacity = 1,
                tooltip = popup_text
                ).add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_8d73181065aa22cd3a288579f7e09ea5 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_8d73181065aa22cd3a288579f7e09ea5&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_8d73181065aa22cd3a288579f7e09ea5 = L.map(
#                 &quot;map_8d73181065aa22cd3a288579f7e09ea5&quot;,
#                 {
#                     center: [36.731948, -93.71588750000001],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 5,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_8630de63634434611fbfdeeb94181700 = L.tileLayer(
#                 &quot;https://stamen-tiles-{s}.a.ssl.fastly.net/terrain/{z}/{x}/{y}.jpg&quot;,
#                 {&quot;attribution&quot;: &quot;Map tiles by \u003ca target=\&quot;_blank\&quot; href=\&quot;http://stamen.com\&quot;\u003eStamen Design\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://creativecommons.org/licenses/by/3.0\&quot;\u003eCC BY 3.0\u003c/a\u003e. Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://creativecommons.org/licenses/by-sa/3.0\&quot;\u003eCC BY SA\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_8d73181065aa22cd3a288579f7e09ea5);
#
#
#             var circle_marker_a734eec4be69e2dd074ed1b1078ad2cc = L.circleMarker(
#                 [34.132644, -86.895744],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;red&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;red&quot;, &quot;fillOpacity&quot;: 1, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 3, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_8d73181065aa22cd3a288579f7e09ea5);
#
#
#             circle_marker_a734eec4be69e2dd074ed1b1078ad2cc.bindTooltip(
#                 `&lt;div&gt;
#                      Day&#x27;s Gap
# Date: 1863-04-30
# Casualities: 88
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var circle_marker_b5f25331557c2f4b81901d5a9b3c00fc = L.circleMarker(
#                 [34.819258, -86.976644],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;red&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;red&quot;, &quot;fillOpacity&quot;: 1, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 3, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_8d73181065aa22cd3a288579f7e09ea5);
#
#
#             circle_marker_b5f25331557c2f4b81901d5a9b3c00fc.bindTooltip(
#                 `&lt;div&gt;
#                      Athens
# Date: 1864-01-26
# Casualities: 50
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var circle_marker_a0af28ea40357a847b0c29e67a021cfd = L.circleMarker(
#                 [30.669382, -88.202374],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;red&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;red&quot;, &quot;fillOpacity&quot;: 1, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 3, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_8d73181065aa22cd3a288579f7e09ea5);
#
#
#             circle_marker_a0af28ea40357a847b0c29e67a021cfd.bindTooltip(
#                 `&lt;div&gt;
#                      Mobile Bay
# Date: 1864-08-02
# Casualities: 1,822
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var circle_marker_ea7dae94da93434a4465e7e9dc415cd2 = L.circleMarker(
#                 [34.434541, -86.847604],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;red&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;red&quot;, &quot;fillOpacity&quot;: 1, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 3, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_8d73181065aa22cd3a288579f7e09ea5);
#
#
#             circle_marker_ea7dae94da93434a4465e7e9dc415cd2.bindTooltip(
#                 `&lt;div&gt;
#                      Decatur
# Date: 1864-10-26
# Casualities: 605
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var circle_marker_b8c32cd94e2d2028879e9cd80a8816e9 = L.circleMa

# %% [markdown]
# When designing a map, users should think about the various ways they can convey information to the viewer. The map above shows all the battles in the database. Users can click on the points to get information about the battle (date, casualities, etc.). But we can actually convey some of this information graphically.
#
# For example, we can vary the size of the marker to indicate the number of casualities. We can also change the color of the marker to indicate the year of the battle.
#
# The former is pretty straightforward: we can set the radius value based on the casuality figures. To ensure the circles are not too small, we can use the `max()` function to select from a default value and the casuality-calculated value.
#
# The latter is a bit more complex: we need to define a `dictionary` with key/value pairs for the years and the colors we wish to use. When we iterate through the dataframe, the color will be set by looking up the values in the dictionary.

# %%
m = folium.Map(location=center, zoom_start = 5)
folium.TileLayer(provider).add_to(m)

color_dict = {'1861':'red','1862':'blue','1863':'green','1864':'purple','1865':'orange'}

for idx,row in df.iterrows():
    popup_text = f"Battle Name: {row.battle_name}\nDate: {row.start_date:%Y-%m-%d}\nCasualities: {row.casualties:,.0f}"
    folium.CircleMarker(location = [row.lat,row.lon],
                radius = max(3,row.casualties/1000),
                color = color_dict[f"{row.start_date:%Y}"],
                fill = True,
                tooltip = popup_text
                ).add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_e66b39105e755de6e619bc2981ef2615 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_e66b39105e755de6e619bc2981ef2615&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_e66b39105e755de6e619bc2981ef2615 = L.map(
#                 &quot;map_e66b39105e755de6e619bc2981ef2615&quot;,
#                 {
#                     center: [36.731948, -93.71588750000001],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 5,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_fc8e598f0add358e99b6bc25b30b350e = L.tileLayer(
#                 &quot;https://stamen-tiles-{s}.a.ssl.fastly.net/terrain/{z}/{x}/{y}.jpg&quot;,
#                 {&quot;attribution&quot;: &quot;Map tiles by \u003ca target=\&quot;_blank\&quot; href=\&quot;http://stamen.com\&quot;\u003eStamen Design\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://creativecommons.org/licenses/by/3.0\&quot;\u003eCC BY 3.0\u003c/a\u003e. Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://creativecommons.org/licenses/by-sa/3.0\&quot;\u003eCC BY SA\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_e66b39105e755de6e619bc2981ef2615);
#
#
#             var circle_marker_0d26a044cb87b9fad8e803567abb652a = L.circleMarker(
#                 [34.132644, -86.895744],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;green&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;green&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 3, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_e66b39105e755de6e619bc2981ef2615);
#
#
#             circle_marker_0d26a044cb87b9fad8e803567abb652a.bindTooltip(
#                 `&lt;div&gt;
#                      Battle Name: Day&#x27;s Gap
# Date: 1863-04-30
# Casualities: 88
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var circle_marker_7687be9e693681db09fddac1368ec240 = L.circleMarker(
#                 [34.819258, -86.976644],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;purple&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;purple&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 3, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_e66b39105e755de6e619bc2981ef2615);
#
#
#             circle_marker_7687be9e693681db09fddac1368ec240.bindTooltip(
#                 `&lt;div&gt;
#                      Battle Name: Athens
# Date: 1864-01-26
# Casualities: 50
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var circle_marker_3abd94f96a3e7cdac3242ccb22c061b1 = L.circleMarker(
#                 [30.669382, -88.202374],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;purple&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;purple&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 3, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_e66b39105e755de6e619bc2981ef2615);
#
#
#             circle_marker_3abd94f96a3e7cdac3242ccb22c061b1.bindTooltip(
#                 `&lt;div&gt;
#                      Battle Name: Mobile Bay
# Date: 1864-08-02
# Casualities: 1,822
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var circle_marker_1eaf3557d3878073869d7b4ff653c927 = L.circleMarker(
#                 [34.434541, -86.847604],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;purple&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;purple&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 3, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_e66b39105e755de6e619bc2981ef2615);
#
#
#             circle_marker_1eaf3557d3878073869d7b4ff653c927.bindTooltip(
#                 `&lt;div&gt;
#                      Battle Name: Decatur
# Date: 1864-10-26
# Casualities: 605
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );

# %% [markdown]
# ## Filter by Year
#
# This map conveys more information than the earlier one: we can see which battles had the most casualities and, by paying attention to the colors, get some idea of how the war progressed.
#
# It might be easier for us to look at one year at a time. This is easy to do with Pandas: we just need to filter the dataframe to select the year we wish to map.

# %%
import datetime

m = folium.Map(location=center, zoom_start = 5)
folium.TileLayer(provider).add_to(m)

year = 1863 # <= specify a year here and use it to filter the date field in the next two rows
filter = (df['start_date'] >= datetime.datetime.strptime(f"{year}-01-01",'%Y-%m-%d')) & \
            (df['start_date'] <= datetime.datetime.strptime(f"{year}-12-31",'%Y-%m-%d'))

for idx,row in df[filter].iterrows(): # <= the filtered DF will only have battles in the year specified
    popup_text = f"Battle Name: {row.battle_name}\nDate: {row.start_date:%Y-%m-%d}\nCasualities: {row.casualties:,.0f}"
    folium.CircleMarker(location = [row.lat,row.lon],
                radius = max(3,row.casualties/1000),
                color = 'red',
                fill = True,
                tooltip = popup_text
                ).add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_07777ac7c953135cdf22b71ebc5646b5 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_07777ac7c953135cdf22b71ebc5646b5&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_07777ac7c953135cdf22b71ebc5646b5 = L.map(
#                 &quot;map_07777ac7c953135cdf22b71ebc5646b5&quot;,
#                 {
#                     center: [36.731948, -93.71588750000001],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 5,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_1144ebff35617e1e82d7660ed65226f4 = L.tileLayer(
#                 &quot;https://stamen-tiles-{s}.a.ssl.fastly.net/terrain/{z}/{x}/{y}.jpg&quot;,
#                 {&quot;attribution&quot;: &quot;Map tiles by \u003ca target=\&quot;_blank\&quot; href=\&quot;http://stamen.com\&quot;\u003eStamen Design\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://creativecommons.org/licenses/by/3.0\&quot;\u003eCC BY 3.0\u003c/a\u003e. Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://creativecommons.org/licenses/by-sa/3.0\&quot;\u003eCC BY SA\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_07777ac7c953135cdf22b71ebc5646b5);
#
#
#             var circle_marker_38de404469be46ee904811cbacf43f47 = L.circleMarker(
#                 [34.132644, -86.895744],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;red&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;red&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 3, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_07777ac7c953135cdf22b71ebc5646b5);
#
#
#             circle_marker_38de404469be46ee904811cbacf43f47.bindTooltip(
#                 `&lt;div&gt;
#                      Battle Name: Day&#x27;s Gap
# Date: 1863-04-30
# Casualities: 88
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var circle_marker_c1173b13a953a2a8dca8f68a65153151 = L.circleMarker(
#                 [34.301756, -91.348247],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;red&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;red&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 6.547, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_07777ac7c953135cdf22b71ebc5646b5);
#
#
#             circle_marker_c1173b13a953a2a8dca8f68a65153151.bindTooltip(
#                 `&lt;div&gt;
#                      Battle Name: Arkansas Post
# Date: 1863-01-09
# Casualities: 6,547
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var circle_marker_90cff538ad35d05f71bee75a1ec33643 = L.circleMarker(
#                 [36.378952, -90.417358],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;red&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;red&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 3, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_07777ac7c953135cdf22b71ebc5646b5);
#
#
#             circle_marker_90cff538ad35d05f71bee75a1ec33643.bindTooltip(
#                 `&lt;div&gt;
#                      Battle Name: Chalk Bluff
# Date: 1863-05-01
# Casualities: nan
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var circle_marker_23651d91973c569ebe4fa93754139b26 = L.circleMarker(
#                 [34.491703, -90.847984],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;red&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;red&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 3, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_07777ac7c953135cdf22b71ebc5646b5);
#
#
#             circle_marker_23651d91973c569ebe4fa93754139b26.bindTooltip(
#                 `&lt;div&gt;
#                      Battle Name: Helena
# Date: 1863-07-04
# Casualities: 1,842
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );

# %% [markdown]
# We could produce a series of maps, year by year, to show the different battles in the civil war.
#
# Folium makes it possible for us to plot these all on the same map by specifying different layers.
#
# In the following map, we loop through the years 1861 to 1855. For each year:
# 1. We define a layer as a `FeatureGroup()` with a specific name (the year value) and add it to the map.
# 1. We create a filtered version of the DF that includes only rows of data for the desired year.
# 1. We iterate through the filtered DF to create our markers. These are added **to the layer** (not to the map, as in earlier examples).
# 1. We have added a tool to add `LayerControl()` to the map. This is a little box in the upper right corner: if you click on it, it will display radio buttons for the different layers, so you can click on the one you want to display.
#
# When we initialized the map, we told Folium **not** to have a basemap (`tiles = None`). This is because if we initialize the map with basetiles, it will appear in the Control box. But we don't want to be able to turn off the basemap! Instead, we add the basemap with the `TileLayer()` method, where we specify `control = False`, to prevent THIS layer from appearing in the control box.

# %%
m = folium.Map(location=center,zoom_start = 5,tiles = None)
folium.TileLayer(provider,overlay=True,control=False).add_to(m)

for year in range(1861,1866):
    layer = folium.FeatureGroup(name = year,overlay = False).add_to(m)

    filter = (df['start_date'] >= datetime.datetime.strptime(f"{year}-01-01",'%Y-%m-%d')) & \
            (df['start_date'] <= datetime.datetime.strptime(f"{year}-12-31",'%Y-%m-%d'))

    for idx,row in df[filter].iterrows():
        popup_text = f"Battle Name: {row.battle_name}\nDate: {row.start_date:%Y-%m-%d}\nCasualities: {row.casualties:,.0f}"
        folium.CircleMarker(location = [row.lat,row.lon],
                    radius = row.casualties/1000,
                    color = 'red',
                    fill = True,
                    tooltip = popup_text
                    ).add_to(layer)

folium.LayerControl().add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_2c1596481f68433c81b482ca75e8a2ce {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_2c1596481f68433c81b482ca75e8a2ce&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_2c1596481f68433c81b482ca75e8a2ce = L.map(
#                 &quot;map_2c1596481f68433c81b482ca75e8a2ce&quot;,
#                 {
#                     center: [36.731948, -93.71588750000001],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 5,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var feature_group_ee90d65b57b8dc38e8eef609256a5625 = L.featureGroup(
#                 {}
#             ).addTo(map_2c1596481f68433c81b482ca75e8a2ce);
#
#
#             var circle_marker_0400530dc99738d5eb73855e88a6ff67 = L.circleMarker(
#                 [30.85988, -87.436304],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;red&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;red&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 0.154, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(feature_group_ee90d65b57b8dc38e8eef609256a5625);
#
#
#             circle_marker_0400530dc99738d5eb73855e88a6ff67.bindTooltip(
#                 `&lt;div&gt;
#                      Battle Name: Santa Rosa Island
# Date: 1861-10-09
# Casualities: 154
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var circle_marker_640b7ed6b11c142e2012e810b90c2b0c = L.circleMarker(
#                 [36.89856, -83.854036],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;red&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;red&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 0.02, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(feature_group_ee90d65b57b8dc38e8eef609256a5625);
#
#
#             circle_marker_640b7ed6b11c142e2012e810b90c2b0c.bindTooltip(
#                 `&lt;div&gt;
#                      Battle Name: Barbourville
# Date: 1861-09-19
# Casualities: 20
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var circle_marker_0e50d102d7aadf5457bf45f045be3292 = L.circleMarker(
#                 [37.12755, -84.117727],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;red&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;red&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 0.078, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(feature_group_ee90d65b57b8dc38e8eef609256a5625);
#
#
#             circle_marker_0e50d102d7aadf5457bf45f045be3292.bindTooltip(
#                 `&lt;div&gt;
#                      Battle Name: Camp Wildcat
# Date: 1861-10-21
# Casualities: 78
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var circle_marker_ca80b27f57d90f98c9cad0b1cd055227 = L.circleMarker(
#                 [37.571671, -82.748636],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;red&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;red&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 0.293, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(feature_group_ee90d65b57b8dc38e8eef609256a5625);
#
#
#             circle_marker_ca80b27f57d90f98c9cad0b1cd055227.bindTooltip(
#                 `&lt;div&gt;
#                      Battle Name: Ivy Mountain
# Date: 1861-11-08
# Casualities: 293
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var circle_marker_3ea6cf1b0a2ba3e1a46bd94dadaabc9f = L.circleMarker(
#                 [37.294492, -85.884709],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;red&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;red&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 0.131, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(feature_group_ee90d65b57b8dc38e8eef609256a5625);
#
#
#             circle_marker_3ea6cf1b0a2ba3e1a46bd94dadaabc9f.bindTooltip(
#                 `&lt;div&gt;
#                      Battle Name: Rowlett&#x27;s S

# %% [markdown]
# ## Group and Heatmap
#
# Folium provides several other visualizations for mapmakers, notably a *cluster visualization* and a *heatmap visualization*. Because the Civil War data isn't particulary good for showing how these tools can be used (they excell when faced with many individual points), we will load the *Washington Post*'s Fatal Force database. We will use this data because we have examined it previously, so it should be familar.

# %% [markdown]
# ### Group / Cluster Map
#
# Folium will group items together and, as the user zooms in, ungroup them to show the individual points.
#
# To use this, we need to import a special Folium tool and tell the system to add a `marker_cluster` layer to the map. (The variable name can, of course, be anything the mapmaker desires.)
# ```python
# from folium.plugins import MarkerCluster
# marker_cluster = folium.plugins.MarkerCluster().add_to(m)
# ```
# When we iterate over the data, rather than adding the points to the map (as we did above), we add them to the `marker_cluster` layer.
#
# We can add any of the markers we described above to the layer (`.Marker()`, `.Circle()`, `.CircleMarker()` etc.); as the user zooms in, these are the points that will be revealed.

# %%
ff_df = pd.read_csv('https://raw.githubusercontent.com/washingtonpost/data-police-shootings/master/v2/fatal-police-shootings-data.csv',parse_dates = ['date'])
ff_df = ff_df[ff_df['latitude'].notna()] # drop rows that do not have lat/lon data

# %%
provider = TileProvider.from_qms("OpenStreetMap.Mapnik")

m = folium.Map(location=[40, -96], zoom_start=4)

folium.TileLayer(provider).add_to(m)
# switching the basemap (tiles) to a modern map that shows streets and other information

from folium.plugins import MarkerCluster
marker_cluster = folium.plugins.MarkerCluster().add_to(m)

for idx,row in ff_df.iterrows():
    lat, lon = row.latitude, row.longitude
    folium.CircleMarker(location=[lat,lon],
        color = 'red',
        radius = 3,
        fill = True,
        fill_opacity = 1
        ).add_to(marker_cluster)

m
# Out:
# Output hidden; open in https://colab.research.google.com to view.

# %% [markdown]
# We can also format the markers using the tools described above.

# %%
m = folium.Map(location=[40, -96], zoom_start=4)
folium.TileLayer(provider).add_to(m)

from folium.plugins import MarkerCluster
marker_cluster = folium.plugins.MarkerCluster().add_to(m)

color_dict = {'2015':'red','2016':'orange','2017':'darkred',
              '2018': 'green','2019':'blue','2020':'purple',
              '2021':'white','2022':'black','2023':'darkgreen'}

for idx,row in ff_df.iterrows():
    popup_text = f"Year:{row.date:%Y}\nRace:{row.race}\nAge:{row.age:.0f}"
    lat, lon = row.latitude, row.longitude
    folium.Marker(location=[lat,lon],
                  icon=folium.Icon(color = color_dict[f"{row.date:%Y}"]
                                  ),
                  tooltip = popup_text,
                  ).add_to(marker_cluster)

m
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-15-2351549130e2> in <cell line: 11>()
#      13     lat, lon = row.latitude, row.longitude
#      14     folium.Marker(location=[lat,lon],
# ---> 15                   icon=folium.Icon(color = color_dict[f"{row.date:%Y}"]
#      16                                   ),
#      17                   tooltip = popup_text,
#
# KeyError: '2024'

# %% [markdown]
# ### Heatmap

# %% [markdown]
# The [heatmap](https://python-visualization.github.io/folium/plugins.html#folium-plugins) tool doesn't allow us to add points with information (as we did above). Instead, it takes just a list of lat/lon points and processes them to create the heatmap. So rather than iterating through the DF, we will just pass the list of lat/lon points to the tool.

# %%
m = folium.Map(location=[40, -96], zoom_start=4)
folium.TileLayer(provider).add_to(m)

from folium.plugins import HeatMap

points = ff_df[['latitude','longitude']].values.tolist()

HeatMap(points,radius = 12).add_to(m)

m

# %% [markdown]
# Folium can present a heatmap of data that changes over time. This doesn't work especially well for the fatal force data because the data is sporadic. It would work better for things like traffic flows along major highways, since there is almost always a low-level base usage, which peaks during rush-hour.
#
# But we can see how to arrange the data so that -- should you get a data set that would work better -- you can use this tool.
#
# The `HeatMapWithTime()` method expects to have two groups of data, of the same length.
# * `data=` needs to be a list of points in the form [lat,lon]
# * `index=` needs to be a list of dates
#
# One way to create this is to set up a dictionary, using some [tools](https://docs.python.org/3/library/collections.html) from the collections library.
#
# The following code creates a dictionary whose default value is a `list`. It iterates over the DF, but since it uses [`itertuples()`](https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.itertuples.html), it returns the values as tuples
#
# For each date (in this case, I've specified Year-Month), it creates a string version of the datetime ("2020-01") as the key and appends a list of lat/lon data for the month.
#
# The data looks like this:
# ```python
#             [('2015-01',
#               [[47.246826, -123.121592],
#                [45.4874214, -122.8916961],
#                [37.694766, -97.280554],
#                [39.380084, -76.820805]]),
#              ('2015-02',
#               [[40.273404, -76.712841],
#                [34.417432, -117.176872],
#                [35.917642, -77.54755],
#                [33.619301, -114.450926]]),
#              ('2015-03',
#               [[34.043131, -118.244634],
#                [29.704199, -95.621853],
#                ...
# ```
# It then uses the `OrderedDict()` tool to sort the dictionary on its first element (the date field).
#
# In the HeatMapWithTime()
# * `list(data.values())` pulls out the values from the dictionary -- the list of lat/lon values -- and turns them into a list.
#
# * `list(data.keys())` does the same thing for the dictionary's keys, which is the dates.
#
# (I found this solution on [Stackoverflow](https://stackoverflow.com/questions/64325958/heatmapwithtime-plugin-in-folium).)

# %%
m = folium.Map(location=[40, -96], zoom_start=4)
folium.TileLayer(provider).add_to(m)

# https://stackoverflow.com/questions/64325958/heatmapwithtime-plugin-in-folium

from folium.plugins import HeatMapWithTime

from collections import defaultdict, OrderedDict

data = defaultdict(list)

for row in ff_df.itertuples():
  data[row.date.strftime("%Y-%m")].append([row.latitude,row.longitude])

data = OrderedDict(sorted(data.items(),key = lambda t: t[0]))

hm = HeatMapWithTime(data = list(data.values()),
                     index = list(data.keys()),
                     radius = 10,
                     auto_play = True)

hm.add_to(m)

m

# %% [markdown]
# # Your Turn
#
# Pick either of the two datasets used above and experiment a bit:
# * Take the Civil War battle data and create a cluster or heat map.
#   * Advanced: make a heatmap with time for the Civil War data.
# * Take the Fatal Force data and draw some maps with Markers or CircleMarkers.
# * Make a map of the FF data that has layers for the different years (2015-2022).
