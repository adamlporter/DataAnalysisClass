# %%
#https://towardsdatascience.com/simple-and-multiple-linear-regression-in-python-c928425168f9

import pandas as pd

# %%
#df = pd.read_csv('/home/alp/Google Drive/Classes/IC230TS/Excel_HW/election-context-2018.csv')
df = pd.read_csv('G:\My Drive\Classes\IC230TS\Excel_HW\election-context-2018.csv')

# %%
df.head(3)
# Out:
#       state     county   fips PctDT PctHC PctOth16 PctMR PctBO PctOth12  \
# 0  Illinois      Adams  17001  71.3  24.0      4.6  66.7  31.5      1.8
# 1  Illinois  Alexander  17003  52.6  44.3      3.1  42.5  56.1      1.4
# 2  Illinois       Bond  17005  64.9  27.5      7.6  55.8  41.2      3.0
#
#   Pct>18yo  ... Unnamed: 30 Unnamed: 31 Unnamed: 32 Unnamed: 33 Unnamed: 34  \
# 0     76.8  ...         NaN         NaN         NaN         NaN         NaN
# 1     75.7  ...         NaN         NaN         NaN         NaN         NaN
# 2     78.5  ...         NaN         NaN         NaN         NaN         NaN
#
#   Unnamed: 35 Unnamed: 36 Unnamed: 37 Unnamed: 38 Unnamed: 39
# 0         NaN         NaN         NaN         NaN         NaN
# 1         NaN         NaN         NaN         NaN         NaN
# 2         NaN         NaN         NaN         NaN         NaN
#
# [3 rows x 40 columns]

# %%
df.tail()
# Out:
#     state county fips PctDT PctHC PctOth16 PctMR PctBO PctOth12 Pct>18yo  ...  \
# 127   NaN    NaN  NaN   NaN   NaN      NaN   NaN   NaN      NaN      NaN  ...
# 128   NaN    NaN  NaN   NaN   NaN      NaN   NaN   NaN      NaN      NaN  ...
# 129   NaN    NaN  NaN   NaN   NaN      NaN   NaN   NaN      NaN      NaN  ...
# 130   NaN    NaN  NaN   NaN   NaN      NaN   NaN   NaN      NaN      NaN  ...
# 131   NaN    NaN  NaN   NaN   NaN      NaN   NaN   NaN      NaN      NaN  ...
#
#     Unnamed: 30 Unnamed: 31 Unnamed: 32 Unnamed: 33 Unnamed: 34 Unnamed: 35  \
# 127         NaN         NaN         NaN         NaN         NaN         NaN
# 128         NaN         NaN         NaN         NaN         NaN         NaN
# 129         NaN         NaN         NaN         NaN         NaN         NaN
# 130         NaN         NaN         NaN         NaN         NaN         NaN
# 131         NaN         NaN         NaN         NaN         NaN         NaN
#
#     Unnamed: 36 Unnamed: 37 Unnamed: 38 Unnamed: 39
# 127         NaN         NaN         NaN         NaN
# 128         NaN         NaN         NaN         NaN
# 129         NaN         NaN         NaN         NaN
# 130         NaN         NaN         NaN         NaN
# 131         NaN         NaN         NaN         NaN
#
# [5 rows x 40 columns]

# %% [markdown]
# Need to clean up the data: drop all these NaN rows.

# %%
df.columns
# Out:
# Index(['state', 'county', 'fips', 'PctDT', 'PctHC', 'PctOth16', 'PctMR',
#        'PctBO', 'PctOth12', 'Pct>18yo', 'PctTurnout', 'white_pct', 'black_pct',
#        'hispanic_pct', 'nonwhite_pct', 'foreignborn_pct', 'female_pct',
#        'age29andunder_pct', 'age65andolder_pct', 'median_hh_inc',
#        'clf_unemploy_pct', 'lesshs_pct', 'lesscollege_pct',
#        'lesshs_whites_pct', 'lesscollege_whites_pct', 'rural_pct',
#        'ruralurban_cc', 'Unnamed: 27', 'Unnamed: 28', 'Unnamed: 29',
#        'Unnamed: 30', 'Unnamed: 31', 'Unnamed: 32', 'Unnamed: 33',
#        'Unnamed: 34', 'Unnamed: 35', 'Unnamed: 36', 'Unnamed: 37',
#        'Unnamed: 38', 'Unnamed: 39'],
#       dtype='object')

# %%
df= df[['state', 'county', 'fips', 'PctDT', 'PctHC', 'PctOth16', 'PctMR',
       'PctBO', 'PctOth12', 'Pct>18yo', 'PctTurnout', 'white_pct', 'black_pct',
       'hispanic_pct', 'nonwhite_pct', 'foreignborn_pct', 'female_pct',
       'age29andunder_pct', 'age65andolder_pct', 'median_hh_inc',
       'clf_unemploy_pct', 'lesshs_pct', 'lesscollege_pct',
       'lesshs_whites_pct', 'lesscollege_whites_pct', 'rural_pct',
       'ruralurban_cc']]
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 132 entries, 0 to 131
# Data columns (total 27 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   state                   102 non-null    object
#  1   county                  125 non-null    object
#  2   fips                    126 non-null    object
#  3   PctDT                   125 non-null    object
#  4   PctHC                   124 non-null    object
#  5   PctOth16                123 non-null    object
#  6   PctMR                   122 non-null    object
#  7   PctBO                   121 non-null    object
#  8   PctOth12                120 non-null    object
#  9   Pct>18yo                119 non-null    object
#  10  PctTurnout              118 non-null    object
#  11  white_pct               117 non-null    object
#  12  black_pct               116 non-null    object
#  13  hispanic_pct            115 non-null    object
#  14  nonwhite_pct            114 non-null    object
#  15  foreignborn_pct         113 non-null    object
#  16  female_pct              112 non-null    object
#  17  age29andunder_pct       111 non-null    object
#  18  age65andolder_pct       110 non-null    object
#  19  median_hh_inc           109 non-null    object
#  20  clf_unemploy_pct        108 non-null    object
#  21  lesshs_pct              107 non-null    object
#  22  lesscollege_pct         106 non-null    object
#  23  lesshs_whites_pct       105 non-null    object
#  24  lesscollege_whites_pct  104 non-null    object
#  25  rural_pct               102 non-null    float64
#  26  ruralurban_cc           102 non-null    float64
# dtypes: float64(2), object(25)
# memory usage: 28.0+ KB

# %% [markdown]
# And need to change teh "object" (string) to numbers (floats)

# %%
df = df.dropna()

# %%
df.tail()
# Out:
#         state      county   fips PctDT PctHC PctOth16 PctMR PctBO PctOth12  \
# 97   Illinois   Whiteside  17195  49.3  43.1      7.6  40.3  57.8      1.9
# 98   Illinois        Will  17197  44.1  50.5      5.4  46.5  52.0      1.5
# 99   Illinois  Williamson  17199  67.7  26.9      5.3  61.5  36.5      2.0
# 100  Illinois   Winnebago  17201  47.0  47.1      5.9  46.3  51.9      1.8
# 101  Illinois    Woodford  17203  66.5  25.6      7.9  68.7  29.5      1.8
#
#     Pct>18yo  ... age29andunder_pct age65andolder_pct median_hh_inc  \
# 97      76.1  ...              36.0              18.9         49151
# 98      68.3  ...              41.2              11.2         77507
# 99      77.2  ...              36.2              17.5         45902
# 100     72.3  ...              38.7              15.6         49468
# 101     74.8  ...              38.4              16.3         68040
#
#     clf_unemploy_pct lesshs_pct lesscollege_pct lesshs_whites_pct  \
# 97               6.8       11.3            82.7               9.7
# 98               6.8        9.2            66.5               4.8
# 99               7.6        9.8            77.9               9.6
# 100             10.5       12.6            77.6               8.8
# 101              5.3        6.0            69.6               5.6
#
#     lesscollege_whites_pct rural_pct ruralurban_cc
# 97                    81.9      37.3           4.0
# 98                    64.3       3.9           1.0
# 99                    78.0      34.8           3.0
# 100                   75.2       7.9           2.0
# 101                   69.5      54.9           2.0
#
# [5 rows x 27 columns]

# %%
col_list = df.columns
col_list[3:]
# Out:
# Index(['PctDT', 'PctHC', 'PctOth16', 'PctMR', 'PctBO', 'PctOth12', 'Pct>18yo',
#        'PctTurnout', 'white_pct', 'black_pct', 'hispanic_pct', 'nonwhite_pct',
#        'foreignborn_pct', 'female_pct', 'age29andunder_pct',
#        'age65andolder_pct', 'median_hh_inc', 'clf_unemploy_pct', 'lesshs_pct',
#        'lesscollege_pct', 'lesshs_whites_pct', 'lesscollege_whites_pct',
#        'rural_pct', 'ruralurban_cc'],
#       dtype='object')

# %%
for col in col_list[3:]:
    df[col] = df[col].astype(float)
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 102 entries, 0 to 101
# Data columns (total 27 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   state                   102 non-null    object
#  1   county                  102 non-null    object
#  2   fips                    102 non-null    object
#  3   PctDT                   102 non-null    float64
#  4   PctHC                   102 non-null    float64
#  5   PctOth16                102 non-null    float64
#  6   PctMR                   102 non-null    float64
#  7   PctBO                   102 non-null    float64
#  8   PctOth12                102 non-null    float64
#  9   Pct>18yo                102 non-null    float64
#  10  PctTurnout              102 non-null    float64
#  11  white_pct               102 non-null    float64
#  12  black_pct               102 non-null    float64
#  13  hispanic_pct            102 non-null    float64
#  14  nonwhite_pct            102 non-null    float64
#  15  foreignborn_pct         102 non-null    float64
#  16  female_pct              102 non-null    float64
#  17  age29andunder_pct       102 non-null    float64
#  18  age65andolder_pct       102 non-null    float64
#  19  median_hh_inc           102 non-null    float64
#  20  clf_unemploy_pct        102 non-null    float64
#  21  lesshs_pct              102 non-null    float64
#  22  lesscollege_pct         102 non-null    float64
#  23  lesshs_whites_pct       102 non-null    float64
#  24  lesscollege_whites_pct  102 non-null    float64
#  25  rural_pct               102 non-null    float64
#  26  ruralurban_cc           102 non-null    float64
# dtypes: float64(24), object(3)
# memory usage: 22.3+ KB

# %% [markdown]
# OK, data should be clean. Let's sample a few counties to check.

# %%
df.sample(5)
# Out:
#        state   county   fips  PctDT  PctHC  PctOth16  PctMR  PctBO  PctOth12  \
# 65  Illinois   Mercer  17131   56.4   36.0       7.6   45.4   52.8       1.8
# 23  Illinois  Edwards  17047   83.0   13.0       4.0   74.5   23.4       2.1
# 31  Illinois   Grundy  17063   57.9   34.7       7.4   53.4   44.5       2.1
# 59  Illinois  Madison  17119   54.1   38.9       7.0   49.5   48.1       2.4
# 43  Illinois  Johnson  17087   76.4   18.8       4.9   69.9   27.7       2.4
#
#     Pct>18yo  ...  age29andunder_pct  age65andolder_pct  median_hh_inc  \
# 65      77.9  ...               33.8               20.3        55750.0
# 23      76.8  ...               35.2               19.4        47035.0
# 31      73.1  ...               39.8               12.9        67162.0
# 59      76.7  ...               38.1               15.6        54573.0
# 43      81.3  ...               33.9               19.0        44179.0
#
#     clf_unemploy_pct  lesshs_pct  lesscollege_pct  lesshs_whites_pct  \
# 65               6.1         8.1             82.5                8.0
# 23               7.2        11.0             88.0               10.8
# 31               7.5         7.1             78.2                5.9
# 59               8.2         7.4             74.3                7.0
# 43               8.9        16.6             83.3               11.7
#
#     lesscollege_whites_pct  rural_pct  ruralurban_cc
# 65                    82.6       77.8            2.0
# 23                    88.3      100.0            9.0
# 31                    78.1       24.4            1.0
# 59                    73.6       13.3            1.0
# 43                    81.2      100.0            8.0
#
# [5 rows x 27 columns]

# %% [markdown]
# Data looks OK.
#
# Let's look at a correlation table for the IL county data. . .

# %%
corr1 = df.corr()
corr1.style.background_gradient(cmap='coolwarm',axis=None).format(precision=3)
# Out:
# /tmp/ipykernel_27125/550126231.py:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   corr1 = df.corr()
# <style type="text/css">
# #T_2b237_row0_col0, #T_2b237_row1_col1, #T_2b237_row2_col2, #T_2b237_row3_col3, #T_2b237_row4_col4, #T_2b237_row5_col5, #T_2b237_row6_col6, #T_2b237_row7_col7, #T_2b237_row8_col8, #T_2b237_row9_col9, #T_2b237_row10_col10, #T_2b237_row11_col11, #T_2b237_row12_col12, #T_2b237_row13_col13, #T_2b237_row14_col14, #T_2b237_row15_col15, #T_2b237_row16_col16, #T_2b237_row17_col17, #T_2b237_row18_col18, #T_2b237_row19_col19, #T_2b237_row20_col20, #T_2b237_row21_col21, #T_2b237_row22_col22, #T_2b237_row23_col23 {
#   background-color: #b40426;
#   color: #f1f1f1;
# }
# #T_2b237_row0_col1, #T_2b237_row1_col0, #T_2b237_row3_col4, #T_2b237_row4_col3, #T_2b237_row8_col11, #T_2b237_row11_col8 {
#   background-color: #3b4cc0;
#   color: #f1f1f1;
# }
# #T_2b237_row0_col2, #T_2b237_row2_col0, #T_2b237_row10_col22, #T_2b237_row16_col23, #T_2b237_row22_col10, #T_2b237_row23_col16 {
#   background-color: #81a4fb;
#   color: #f1f1f1;
# }
# #T_2b237_row0_col3, #T_2b237_row3_col0 {
#   background-color: #c73635;
#   color: #f1f1f1;
# }
# #T_2b237_row0_col4, #T_2b237_row1_col3, #T_2b237_row3_col1, #T_2b237_row4_col0 {
#   background-color: #4961d2;
#   color: #f1f1f1;
# }
# #T_2b237_row0_col5, #T_2b237_row1_col13, #T_2b237_row5_col0, #T_2b237_row9_col12, #T_2b237_row12_col9, #T_2b237_row13_col1 {
#   background-color: #f4c5ad;
#   color: #000000;
# }
# #T_2b237_row0_col6, #T_2b237_row6_col0, #T_2b237_row7_col8, #T_2b237_row8_col7, #T_2b237_row19_col23, #T_2b237_row23_col19 {
#   background-color: #ee8468;
#   color: #f1f1f1;
# }
# #T_2b237_row0_col7, #T_2b237_row4_col14, #T_2b237_row7_col0, #T_2b237_row14_col4 {
#   background-color: #f7b89c;
#   color: #000000;
# }
# #T_2b237_row0_col8, #T_2b237_row8_col0, #T_2b237_row15_col22, #T_2b237_row22_col15 {
#   background-color: #dd5f4b;
#   color: #f1f1f1;
# }
# #T_2b237_row0_col9, #T_2b237_row3_col9, #T_2b237_row7_col10, #T_2b237_row9_col0, #T_2b237_row9_col3, #T_2b237_row10_col7 {
#   background-color: #97b8ff;
#   color: #000000;
# }
# #T_2b237_row0_col10, #T_2b237_row1_col22, #T_2b237_row10_col0, #T_2b237_row14_col22, #T_2b237_row22_col1, #T_2b237_row22_col14 {
#   background-color: #6f92f3;
#   color: #f1f1f1;
# }
# #T_2b237_row0_col11, #T_2b237_row0_col12, #T_2b237_row11_col0, #T_2b237_row12_col0 {
#   background-color: #6180e9;
#   color: #f1f1f1;
# }
# #T_2b237_row0_col13, #T_2b237_row8_col17, #T_2b237_row11_col20, #T_2b237_row13_col0, #T_2b237_row13_col19, #T_2b237_row17_col8, #T_2b237_row19_col13, #T_2b237_row20_col11 {
#   background-color: #bad0f8;
#   color: #000000;
# }
# #T_2b237_row0_col14, #T_2b237_row14_col0 {
#   background-color: #82a6fb;
#   color: #f1f1f1;
# }
# #T_2b237_row0_col15, #T_2b237_row1_col14, #T_2b237_row14_col1, #T_2b237_row15_col0 {
#   background-color: #f18f71;
#   color: #f1f1f1;
# }
# #T_2b237_row0_col16, #T_2b237_row4_col19, #T_2b237_row16_col0, #T_2b237_row19_col4 {
#   background-color: #9dbdff;
#   color: #000000;
# }
# #T_2b237_row0_col17, #T_2b237_row17_col0 {
#   background-color: #d1dae9;
#   color: #000000;
# }
# #T_2b237_row0_col18, #T_2b237_row5_col22, #T_2b237_row18_col0, #T_2b237_row22_col5 {
#   background-color: #f3c7b1;
#   color: #000000;
# }
# #T_2b237_row0_col19, #T_2b237_row19_col0 {
#   background-color: #e36b54;
#   color: #f1f1f1;
# }
# #T_2b237_row0_col20, #T_2b237_row10_col16, #T_2b237_row12_col14, #T_2b237_row14_col12, #T_2b237_row15_col23, #T_2b237_row16_col10, #T_2b237_row20_col0, #T_2b237_row23_col15 {
#   background-color: #f39475;
#   color: #000000;
# }
# #T_2b237_row0_col21, #T_2b237_row21_col0 {
#   background-color: #de614d;
#   color: #f1f1f1;
# }
# #T_2b237_row0_col22, #T_2b237_row19_col22, #T_2b237_row22_col0, #T_2b237_row22_col19 {
#   background-color: #e7745b;
#   color: #f1f1f1;
# }
# #T_2b237_row0_col23, #T_2b237_row4_col11, #T_2b237_row8_col15, #T_2b237_row11_col4, #T_2b237_row15_col8, #T_2b237_row23_col0 {
#   background-color: #ea7b60;
#   color: #f1f1f1;
# }
# #T_2b237_row1_col2, #T_2b237_row2_col1, #T_2b237_row8_col19, #T_2b237_row19_col8 {
#   background-color: #f59d7e;
#   color: #000000;
# }
# #T_2b237_row1_col4, #T_2b237_row4_col1 {
#   background-color: #c43032;
#   color: #f1f1f1;
# }
# #T_2b237_row1_col5, #T_2b237_row5_col1 {
#   background-color: #b5cdfa;
#   color: #000000;
# }
# #T_2b237_row1_col6, #T_2b237_row6_col1 {
#   background-color: #799cf8;
#   color: #f1f1f1;
# }
# #T_2b237_row1_col7, #T_2b237_row5_col13, #T_2b237_row7_col1, #T_2b237_row13_col5 {
#   background-color: #a9c6fd;
#   color: #000000;
# }
# #T_2b237_row1_col8, #T_2b237_row8_col1, #T_2b237_row8_col9, #T_2b237_row9_col8 {
#   background-color: #5a78e4;
#   color: #f1f1f1;
# }
# #T_2b237_row1_col9, #T_2b237_row9_col1 {
#   background-color: #f59c7d;
#   color: #000000;
# }
# #T_2b237_row1_col10, #T_2b237_row10_col1, #T_2b237_row15_col19, #T_2b237_row19_col15 {
#   background-color: #e57058;
#   color: #f1f1f1;
# }
# #T_2b237_row1_col11, #T_2b237_row9_col11, #T_2b237_row11_col1, #T_2b237_row11_col9, #T_2b237_row18_col20, #T_2b237_row20_col18 {
#   background-color: #d75445;
#   color: #f1f1f1;
# }
# #T_2b237_row1_col12, #T_2b237_row11_col12, #T_2b237_row12_col1, #T_2b237_row12_col11 {
#   background-color: #dc5d4a;
#   color: #f1f1f1;
# }
# #T_2b237_row1_col15, #T_2b237_row15_col1 {
#   background-color: #84a7fc;
#   color: #f1f1f1;
# }
# #T_2b237_row1_col16, #T_2b237_row16_col1, #T_2b237_row17_col20, #T_2b237_row20_col17 {
#   background-color: #f7b093;
#   color: #000000;
# }
# #T_2b237_row1_col17, #T_2b237_row17_col1 {
#   background-color: #ecd3c5;
#   color: #000000;
# }
# #T_2b237_row1_col18, #T_2b237_row9_col16, #T_2b237_row16_col9, #T_2b237_row18_col1 {
#   background-color: #c3d5f4;
#   color: #000000;
# }
# #T_2b237_row1_col19, #T_2b237_row19_col1 {
#   background-color: #6c8ff1;
#   color: #f1f1f1;
# }
# #T_2b237_row1_col20, #T_2b237_row20_col1 {
#   background-color: #8fb1fe;
#   color: #000000;
# }
# #T_2b237_row1_col21, #T_2b237_row16_col20, #T_2b237_row20_col16, #T_2b237_row21_col1 {
#   background-color: #6485ec;
#   color: #f1f1f1;
# }
# #T_2b237_row1_col23, #T_2b237_row6_col11, #T_2b237_row11_col6, #T_2b237_row12_col22, #T_2b237_row22_col12, #T_2b237_row23_col1 {
#   background-color: #779af7;
#   color: #f1f1f1;
# }
# #T_2b237_row2_col3, #T_2b237_row3_col2, #T_2b237_row10_col20, #T_2b237_row14_col20, #T_2b237_row20_col10, #T_2b237_row20_col14 {
#   background-color: #9bbcff;
#   color: #000000;
# }
# #T_2b237_row2_col4, #T_2b237_row4_col2 {
#   background-color: #f7aa8c;
#   color: #000000;
# }
# #T_2b237_row2_col5, #T_2b237_row5_col2, #T_2b237_row5_col14, #T_2b237_row6_col17, #T_2b237_row10_col17, #T_2b237_row14_col5, #T_2b237_row15_col17, #T_2b237_row17_col6, #T_2b237_row17_col10, #T_2b237_row17_col15 {
#   background-color: #e1dad6;
#   color: #000000;
# }
# #T_2b237_row2_col6, #T_2b237_row6_col2 {
#   background-color: #bed2f6;
#   color: #000000;
# }
# #T_2b237_row2_col7, #T_2b237_row7_col2 {
#   background-color: #cfdaea;
#   color: #000000;
# }
# #T_2b237_row2_col8, #T_2b237_row8_col2 {
#   background-color: #ccd9ed;
#   color: #000000;
# }
# #T_2b237_row2_col9, #T_2b237_row9_col2, #T_2b237_row9_col19, #T_2b237_row19_col9 {
#   background-color: #cad8ef;
#   color: #000000;
# }
# #T_2b237_row2_col10, #T_2b237_row10_col2 {
#   background-color: #f5c1a9;
#   color: #000000;
# }
# #T_2b237_row2_col11, #T_2b237_row7_col16, #T_2b237_row11_col2, #T_2b237_row16_col7 {
#   background-color: #ebd3c6;
#   color: #000000;
# }
# #T_2b237_row2_col12, #T_2b237_row12_col2 {
#   background-color: #f6bda2;
#   color: #000000;
# }
# #T_2b237_row2_col13, #T_2b237_row13_col2 {
#   background-color: #ead5c9;
#   color: #000000;
# }
# #T_2b237_row2_col14, #T_2b237_row14_col2 {
#   background-color: #f7ad90;
#   color: #000000;
# }
# #T_2b237_row2_col15, #T_2b237_row3_col14, #T_2b237_row14_col3, #T_2b237_row15_col2 {
#   background-color: #aac7fd;
#   color: #000000;
# }
# #T_2b237_row2_col16, #T_2b237_row16_col2 {
#   background-color: #f7a688;
#   color: #000000;
# }
# #T_2b237_row2_col17, #T_2b237_row13_col23, #T_2b237_row17_col2, #T_2b237_row23_col13 {
#   background-color: #b9d0f9;
#   color: #000000;
# }
# #T_2b237_row2_col18, #T_2b237_row12_col20, #T_2b237_row18_col2, #T_2b237_row20_col12 {
#   background-color: #8badfd;
#   color: #000000;
# }
# #T_2b237_row2_col19, #T_2b237_row19_col2 {
#   background-color: #85a8fc;
#   color: #f1f1f1;
# }
# #T_2b237_row2_col20, #T_2b237_row10_col15,

# %% [markdown]
# Let's set up a regression analysis to see which of these variables is most important in determining pct vote for DT.

# %%
import statsmodels.api as sm

# %%
y = df['PctDT'] # dependent
x = df['PctMR'] # independent
x = sm.add_constant(x)

model = sm.OLS(y,x).fit()
predictions = model.predict(x)

print(model.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  PctDT   R-squared:                       0.801
# Model:                            OLS   Adj. R-squared:                  0.799
# Method:                 Least Squares   F-statistic:                     401.6
# Date:                Mon, 06 Feb 2023   Prob (F-statistic):           8.52e-37
# Time:                        21:01:33   Log-Likelihood:                -316.10
# No. Observations:                 102   AIC:                             636.2
# Df Residuals:                     100   BIC:                             641.4
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         -1.6683      3.259     -0.512      0.610      -8.134       4.798
# PctMR          1.1315      0.056     20.040      0.000       1.020       1.244
# ==============================================================================
# Omnibus:                        5.753   Durbin-Watson:                   1.705
# Prob(Omnibus):                  0.056   Jarque-Bera (JB):                5.312
# Skew:                          -0.549   Prob(JB):                       0.0702
# Kurtosis:                       3.206   Cond. No.                         351.
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %% [markdown]
# PctMR coeff means that for every point support for Romney (2012) increased, there was a 1.13 increase for support of Trump (2016).
#
# So our regression equation is $ PctDT  =  -1.668 + 1.1315 * PctMR $
#
# $ R^2 = 0.801 $ means that this equation explains about 80% of support for Trump based on support for Romney.
#
# How does this compare with support for HC by Obama?

# %%
y = df['PctHC']
x = df['PctBO']
x = sm.add_constant(x)

model = sm.OLS(y,x).fit()
predictions = model.predict(x)

print(model.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  PctHC   R-squared:                       0.822
# Model:                            OLS   Adj. R-squared:                  0.820
# Method:                 Least Squares   F-statistic:                     461.1
# Date:                Mon, 06 Feb 2023   Prob (F-statistic):           3.10e-39
# Time:                        21:01:52   Log-Likelihood:                -303.71
# No. Observations:                 102   AIC:                             611.4
# Df Residuals:                     100   BIC:                             616.7
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const        -12.5320      2.093     -5.988      0.000     -16.684      -8.380
# PctBO          1.0669      0.050     21.473      0.000       0.968       1.165
# ==============================================================================
# Omnibus:                        6.268   Durbin-Watson:                   1.772
# Prob(Omnibus):                  0.044   Jarque-Bera (JB):                5.703
# Skew:                           0.499   Prob(JB):                       0.0577
# Kurtosis:                       3.589   Cond. No.                         186.
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %% [markdown]
# It seems like support for Romney was a stronger predictor for support for DT (1.13) than support for Obama was for HC (1.0669). (I think.)
#
# Let's try some multivariate regressions. . .
#
# If I take variables that are positively correlated with support for DT, what sort of MLR can we get?

# %%
df.columns
# Out:
# Index(['state', 'county', 'fips', 'PctDT', 'PctHC', 'PctOth16', 'PctMR',
#        'PctBO', 'PctOth12', 'Pct>18yo', 'PctTurnout', 'white_pct', 'black_pct',
#        'hispanic_pct', 'nonwhite_pct', 'foreignborn_pct', 'female_pct',
#        'age29andunder_pct', 'age65andolder_pct', 'median_hh_inc',
#        'clf_unemploy_pct', 'lesshs_pct', 'lesscollege_pct',
#        'lesshs_whites_pct', 'lesscollege_whites_pct', 'rural_pct',
#        'ruralurban_cc'],
#       dtype='object')

# %%
y = df['PctDT'] # dependent varible
x = df[['white_pct','age65andolder_pct','median_hh_inc','lesshs_pct', 'lesscollege_pct','rural_pct','ruralurban_cc' ]] # independent variable(s)
x = sm.add_constant(x)

model = sm.OLS(y,x).fit()
predictions = model.predict(x)

print(model.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  PctDT   R-squared:                       0.803
# Model:                            OLS   Adj. R-squared:                  0.788
# Method:                 Least Squares   F-statistic:                     54.72
# Date:                Mon, 06 Feb 2023   Prob (F-statistic):           2.04e-30
# Time:                        21:02:04   Log-Likelihood:                -315.50
# No. Observations:                 102   AIC:                             647.0
# Df Residuals:                      94   BIC:                             668.0
# Df Model:                           7
# Covariance Type:            nonrobust
# =====================================================================================
#                         coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------------
# const               -36.2066     11.423     -3.170      0.002     -58.887     -13.526
# white_pct             0.7747      0.088      8.847      0.000       0.601       0.949
# age65andolder_pct    -1.0808      0.316     -3.418      0.001      -1.709      -0.453
# median_hh_inc      3.985e-05   7.92e-05      0.503      0.616      -0.000       0.000
# lesshs_pct            0.7513      0.276      2.721      0.008       0.203       1.300
# lesscollege_pct       0.4223      0.145      2.918      0.004       0.135       0.710
# rural_pct             0.0414      0.036      1.161      0.249      -0.029       0.112
# ruralurban_cc         0.9605      0.329      2.919      0.004       0.307       1.614
# ==============================================================================
# Omnibus:                        4.685   Durbin-Watson:                   2.166
# Prob(Omnibus):                  0.096   Jarque-Bera (JB):                4.187
# Skew:                          -0.487   Prob(JB):                        0.123
# Kurtosis:                       3.192   Cond. No.                     1.08e+06
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 1.08e+06. This might indicate that there are
# strong multicollinearity or other numerical problems.

# %% [markdown]
# So these variables -- which are positively correlated with voting for DT -- achieve an $R^2$ of 0.803.
#
# Let's look at a different set of variables -- those that are positively correclated with HC -- to see what happens.

# %%
y = df['PctHC'] # dependent varible
x = df[['black_pct', 'hispanic_pct', 'nonwhite_pct', 'female_pct',
       'age29andunder_pct',  'median_hh_inc','lesshs_pct', 'lesscollege_pct',
       'rural_pct', 'ruralurban_cc']]
x = sm.add_constant(x)

model = sm.OLS(y,x).fit()
predictions = model.predict(x)


print(model.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  PctHC   R-squared:                       0.838
# Model:                            OLS   Adj. R-squared:                  0.820
# Method:                 Least Squares   F-statistic:                     47.01
# Date:                Mon, 06 Feb 2023   Prob (F-statistic):           1.26e-31
# Time:                        21:02:17   Log-Likelihood:                -298.90
# No. Observations:                 102   AIC:                             619.8
# Df Residuals:                      91   BIC:                             648.7
# Df Model:                          10
# Covariance Type:            nonrobust
# =====================================================================================
#                         coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------------
# const                85.5516     25.205      3.394      0.001      35.485     135.618
# black_pct             0.1434      0.439      0.327      0.745      -0.728       1.015
# hispanic_pct          0.7009      0.437      1.604      0.112      -0.167       1.569
# nonwhite_pct          0.4780      0.394      1.213      0.228      -0.304       1.260
# female_pct            0.4848      0.252      1.923      0.058      -0.016       0.986
# age29andunder_pct    -0.5612      0.199     -2.814      0.006      -0.957      -0.165
# median_hh_inc        -0.0003   9.16e-05     -3.661      0.000      -0.001      -0.000
# lesshs_pct           -0.8568      0.247     -3.466      0.001      -1.348      -0.366
# lesscollege_pct      -0.4687      0.164     -2.853      0.005      -0.795      -0.142
# rural_pct             0.0062      0.029      0.213      0.832      -0.052       0.064
# ruralurban_cc        -0.9511      0.297     -3.199      0.002      -1.542      -0.360
# ==============================================================================
# Omnibus:                       10.223   Durbin-Watson:                   2.074
# Prob(Omnibus):                  0.006   Jarque-Bera (JB):               10.305
# Skew:                           0.686   Prob(JB):                      0.00579
# Kurtosis:                       3.738   Cond. No.                     2.77e+06
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 2.77e+06. This might indicate that there are
# strong multicollinearity or other numerical problems.

# %% [markdown]
# What happens if we use ALL the demographic variables? Do we increase the $R^2$?

# %%
y = df['PctHC'] # dependent varible
x = df[['white_pct', 'black_pct',
       'hispanic_pct', 'nonwhite_pct', 'foreignborn_pct', 'female_pct',
       'age29andunder_pct', 'age65andolder_pct', 'median_hh_inc',
       'clf_unemploy_pct', 'lesshs_pct', 'lesscollege_pct',
       'lesshs_whites_pct', 'lesscollege_whites_pct', 'rural_pct',
       'ruralurban_cc']]
x = sm.add_constant(x)

model = sm.OLS(y,x).fit()
predictions = model.predict(x)

print(model.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  PctHC   R-squared:                       0.847
# Model:                            OLS   Adj. R-squared:                  0.821
# Method:                 Least Squares   F-statistic:                     31.78
# Date:                Mon, 06 Feb 2023   Prob (F-statistic):           1.10e-28
# Time:                        21:02:22   Log-Likelihood:                -295.87
# No. Observations:                 102   AIC:                             623.7
# Df Residuals:                      86   BIC:                             665.7
# Df Model:                          15
# Covariance Type:            nonrobust
# ==========================================================================================
#                              coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------------------
# const                      0.0186      0.009      2.133      0.036       0.001       0.036
# white_pct                  0.6634      0.349      1.902      0.061      -0.030       1.357
# black_pct                  0.1775      0.555      0.320      0.750      -0.926       1.281
# hispanic_pct               0.8508      0.455      1.869      0.065      -0.054       1.756
# nonwhite_pct               1.1968      0.624      1.919      0.058      -0.043       2.437
# foreignborn_pct           -0.0573      0.565     -0.101      0.919      -1.179       1.065
# female_pct                 0.0291      0.347      0.084      0.933      -0.661       0.719
# age29andunder_pct         -0.1589      0.360     -0.441      0.660      -0.875       0.558
# age65andolder_pct          0.8467      0.495      1.711      0.091      -0.137       1.831
# median_hh_inc             -0.0002      0.000     -1.218      0.227      -0.000       0.000
# clf_unemploy_pct           0.1094      0.337      0.325      0.746      -0.560       0.779
# lesshs_pct                -1.3444      0.649     -2.073      0.041      -2.634      -0.055
# lesscollege_pct           -0.6622      0.594     -1.115      0.268      -1.843       0.519
# lesshs_whites_pct          0.6826      0.690      0.990      0.325      -0.689       2.054
# lesscollege_whites_pct     0.2139      0.532      0.402      0.688      -0.843       1.271
# rural_pct                 -0.0263      0.033     -0.788      0.433      -0.093       0.040
# ruralurban_cc             -0.8023      0.309     -2.596      0.011      -1.417      -0.188
# ==============================================================================
# Omnibus:                        7.093   Durbin-Watson:                   1.909
# Prob(Omnibus):                  0.029   Jarque-Bera (JB):                8.126
# Skew:                           0.392   Prob(JB):                       0.0172
# Kurtosis:                       4.139   Cond. No.                     1.07e+21
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The smallest eigenvalue is 2.43e-31. This might indicate that there are
# strong multicollinearity problems or that the design matrix is singular.

# %% [markdown]
# So we go from $R^2$ of 83.8 to 86.4. A bit better, but not much. . .

# %%
y = df['PctDT'] # dependent varible
x = df[['Pct>18yo', 'PctTurnout', 'white_pct', 'black_pct',
       'hispanic_pct', 'nonwhite_pct', 'foreignborn_pct', 'female_pct',
       'age29andunder_pct', 'age65andolder_pct', 'median_hh_inc',
       'clf_unemploy_pct', 'lesshs_pct', 'lesscollege_pct',
       'lesshs_whites_pct', 'lesscollege_whites_pct', 'rural_pct',
       'ruralurban_cc']]
x = sm.add_constant(x)

model = sm.OLS(y,x).fit()
predictions = model.predict(x)

print(model.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  PctDT   R-squared:                       0.855
# Model:                            OLS   Adj. R-squared:                  0.825
# Method:                 Least Squares   F-statistic:                     29.08
# Date:                Mon, 06 Feb 2023   Prob (F-statistic):           4.41e-28
# Time:                        21:02:41   Log-Likelihood:                -299.94
# No. Observations:                 102   AIC:                             635.9
# Df Residuals:                      84   BIC:                             683.1
# Df Model:                          17
# Covariance Type:            nonrobust
# ==========================================================================================
#                              coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------------------
# const                      0.0367      0.016      2.231      0.028       0.004       0.069
# Pct>18yo                  -1.6386      0.482     -3.402      0.001      -2.596      -0.681
# PctTurnout                 0.2249      0.268      0.839      0.404      -0.308       0.758
# white_pct                  1.9231      0.735      2.615      0.011       0.461       3.386
# black_pct                 -0.5887      0.614     -0.959      0.341      -1.810       0.633
# hispanic_pct              -1.6710      0.528     -3.167      0.002      -2.720      -0.622
# nonwhite_pct               1.7484      0.985      1.774      0.080      -0.211       3.708
# foreignborn_pct           -0.4204      0.640     -0.656      0.513      -1.694       0.853
# female_pct                -1.1959      0.518     -2.309      0.023      -2.226      -0.166
# age29andunder_pct          0.2699      0.442      0.610      0.543      -0.609       1.149
# age65andolder_pct         -0.3860      0.559     -0.691      0.492      -1.497       0.725
# median_hh_inc           4.774e-05      0.000      0.308      0.759      -0.000       0.000
# clf_unemploy_pct           0.2109      0.365      0.578      0.565      -0.514       0.936
# lesshs_pct                 1.0433      0.703      1.483      0.142      -0.355       2.442
# lesscollege_pct            1.4192      0.642      2.212      0.030       0.143       2.695
# lesshs_whites_pct         -0.4129      0.728     -0.567      0.572      -1.860       1.034
# lesscollege_whites_pct    -0.9250      0.571     -1.621      0.109      -2.060       0.210
# rural_pct                  0.0101      0.040      0.252      0.802      -0.070       0.090
# ruralurban_cc              0.8953      0.327      2.737      0.008       0.245       1.546
# ==============================================================================
# Omnibus:                        8.021   Durbin-Watson:                   2.044
# Prob(Omnibus):                  0.018   Jarque-Bera (JB):               10.662
# Skew:                          -0.374   Prob(JB):                      0.00484
# Kurtosis:                       4.396   Cond. No.                     3.81e+20
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The smallest eigenvalue is 1.92e-30. This might indicate that there are
# strong multicollinearity problems or that the design matrix is singular.

# %% [markdown]
# When we do the calculation for DT, we go from $R^2$ of 80.3 to 85.5. This is a bigger gain than for HC, but our first DT MLR didn't have as many variables, so it's hard to compare these.

# %% [markdown]
# Now, let's get the national data (which will include the 102 counties in IL) and see how the same variables work on the larger data set.

# %%
import pandas as pd
nation = pd.read_excel('G:\My Drive\Classes\IC230TS\Excel_HW\election-context-2018.xlsx',engine='openpyxl')
nation.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3114 entries, 0 to 3113
# Data columns (total 43 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   state                   3114 non-null   object
#  1   county                  3114 non-null   object
#  2   fips                    3114 non-null   int64
#  3   trump16                 3114 non-null   int64
#  4   pctDT                   3113 non-null   float64
#  5   clinton16               3114 non-null   int64
#  6   pctHC                   3113 non-null   float64
#  7   otherpres16             3114 non-null   int64
#  8   total16                 3114 non-null   int64
#  9   romney12                3114 non-null   int64
#  10  obama12                 3114 non-null   int64
#  11  otherpres12             3114 non-null   int64
#  12  total12                 3114 non-null   int64
#  13  demsen16                1942 non-null   float64
#  14  repsen16                1942 non-null   float64
#  15  othersen16              1942 non-null   float64
#  16  demhouse16              2862 non-null   float64
#  17  rephouse16              2862 non-null   float64
#  18  otherhouse16            2862 non-null   float64
#  19  demgov16                601 non-null    float64
#  20  repgov16                601 non-null    float64
#  21  othergov16              601 non-null    float64
#  22  repgov14                2148 non-null   float64
#  23  demgov14                2148 non-null   float64
#  24  othergov14              2148 non-null   float64
#  25  total_population        3111 non-null   float64
#  26  cvap                    3111 non-null   float64
#  27  white_pct               3111 non-null   float64
#  28  black_pct               3111 non-null   float64
#  29  hispanic_pct            3111 non-null   float64
#  30  nonwhite_pct            3111 non-null   float64
#  31  foreignborn_pct         3111 non-null   float64
#  32  female_pct              3111 non-null   float64
#  33  age29andunder_pct       3111 non-null   float64
#  34  age65andolder_pct       3111 non-null   float64
#  35  median_hh_inc           3111 non-null   float64
#  36  clf_unemploy_pct        3111 non-null   float64
#  37  lesshs_pct              3111 non-null   float64
#  38  lesscollege_pct         3111 non-null   float64
#  39  lesshs_whites_pct       3111 non-null   float64
#  40  lesscollege_whites_pct  3111 non-null   float64
#  41  rural_pct               3113 non-null   float64
#  42  ruralurban_cc           3113 non-null   float64
# dtypes: float64(32), int64(9), object(2)
# memory usage: 1.0+ MB

# %%
nation = nation.fillna(0)

# %%
nation.columns
# Out:
# Index(['state', 'county', 'fips', 'trump16', 'pctDT', 'clinton16', 'pctHC',
#        'otherpres16', 'total16', 'romney12', 'obama12', 'otherpres12',
#        'total12', 'demsen16', 'repsen16', 'othersen16', 'demhouse16',
#        'rephouse16', 'otherhouse16', 'demgov16', 'repgov16', 'othergov16',
#        'repgov14', 'demgov14', 'othergov14', 'total_population', 'cvap',
#        'white_pct', 'black_pct', 'hispanic_pct', 'nonwhite_pct',
#        'foreignborn_pct', 'female_pct', 'age29andunder_pct',
#        'age65andolder_pct', 'median_hh_inc', 'clf_unemploy_pct', 'lesshs_pct',
#        'lesscollege_pct', 'lesshs_whites_pct', 'lesscollege_whites_pct',
#        'rural_pct', 'ruralurban_cc'],
#       dtype='object')

# %%
nation.sample(5)
# Out:
#           state    county   fips  trump16      pctDT  clinton16      pctHC  \
# 230    Colorado     Delta   8029    11655  69.416319       4087  24.341870
# 452     Georgia  McIntosh  13191     3487  59.071658       2303  39.014061
# 1105  Louisiana    Iberia  22045    20903  64.408085      10698  32.963579
# 1815   New York  Franklin  36033     8221  48.495753       7297  43.045068
# 472     Georgia      Polk  13233    11014  77.481534       2867  20.168836
#
#       otherpres16  total16  romney12  ...  age29andunder_pct  \
# 230          1048    16790     10915  ...          32.358294
# 452           113     5903      3409  ...          30.801234
# 1105          853    32454     20892  ...          42.332552
# 1815         1434    16952      5231  ...          36.947870
# 472           334    14215      9811  ...          41.342122
#
#       age65andolder_pct  median_hh_inc  clf_unemploy_pct  lesshs_pct  \
# 230           23.324840        42011.0          9.153575   11.989151
# 452           20.120508        45248.0          9.929773   17.604197
# 1105          13.599100        44573.0         11.173695   22.209812
# 1815          14.929323        49782.0          8.549105   14.641301
# 472           14.880159        39356.0          8.730637   24.288622
#
#       lesscollege_pct  lesshs_whites_pct  lesscollege_whites_pct  rural_pct  \
# 230         80.393509           7.985870               78.295777  63.172008
# 452         86.233362          19.032550               83.167571  74.311030
# 1105        86.255585          18.606939               83.203253  28.136264
# 1815        81.598503          12.170530               80.182710  62.675633
# 472         87.015726          20.202939               86.229838  51.421338
#
#       ruralurban_cc
# 230             6.0
# 452             3.0
# 1105            2.0
# 1815            7.0
# 472             4.0
#
# [5 rows x 43 columns]

# %% [markdown]
# First, DT on the smaller set of variables.

# %%
y = nation['pctDT'] # dependent varible
x = nation[['white_pct','age65andolder_pct','median_hh_inc','lesshs_pct', 'lesscollege_pct','rural_pct','ruralurban_cc' ]] # independent variable(s)
x = sm.add_constant(x)

model = sm.OLS(y,x).fit()
predictions = model.predict(x)

print(model.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  pctDT   R-squared:                       0.569
# Model:                            OLS   Adj. R-squared:                  0.568
# Method:                 Least Squares   F-statistic:                     585.1
# Date:                Mon, 06 Feb 2023   Prob (F-statistic):               0.00
# Time:                        21:03:03   Log-Likelihood:                -11698.
# No. Observations:                3114   AIC:                         2.341e+04
# Df Residuals:                    3106   BIC:                         2.346e+04
# Df Model:                           7
# Covariance Type:            nonrobust
# =====================================================================================
#                         coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------------
# const               -43.6468      2.875    -15.184      0.000     -49.283     -38.011
# white_pct             0.4538      0.013     35.105      0.000       0.428       0.479
# age65andolder_pct    -0.1251      0.053     -2.366      0.018      -0.229      -0.021
# median_hh_inc         0.0002   2.11e-05      9.899      0.000       0.000       0.000
# lesshs_pct            0.4899      0.047     10.433      0.000       0.398       0.582
# lesscollege_pct       0.6407      0.032     20.258      0.000       0.579       0.703
# rural_pct             0.0435      0.009      4.928      0.000       0.026       0.061
# ruralurban_cc         0.7584      0.096      7.897      0.000       0.570       0.947
# ==============================================================================
# Omnibus:                       22.551   Durbin-Watson:                   1.106
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               33.704
# Skew:                           0.003   Prob(JB):                     4.80e-08
# Kurtosis:                       3.510   Cond. No.                     7.64e+05
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 7.64e+05. This might indicate that there are
# strong multicollinearity or other numerical problems.

# %%
y = nation['pctHC'] # dependent varible
x = nation[['black_pct', 'hispanic_pct', 'nonwhite_pct', 'female_pct',
       'age29andunder_pct',  'median_hh_inc','lesshs_pct', 'lesscollege_pct',
       'rural_pct', 'ruralurban_cc']]
x = sm.add_constant(x) 

model = sm.OLS(y,x).fit()
predictions = model.predict(x)

print(model.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  pctHC   R-squared:                       0.626
# Model:                            OLS   Adj. R-squared:                  0.625
# Method:                 Least Squares   F-statistic:                     518.9
# Date:                Sun, 19 Feb 2023   Prob (F-statistic):               0.00
# Time:                        09:55:45   Log-Likelihood:                -11380.
# No. Observations:                3114   AIC:                         2.278e+04
# Df Residuals:                    3103   BIC:                         2.285e+04
# Df Model:                          10
# Covariance Type:            nonrobust
# =====================================================================================
#                         coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------------
# const                80.4495      3.914     20.556      0.000      72.776      88.123
# black_pct             0.1044      0.026      3.953      0.000       0.053       0.156
# hispanic_pct         -0.1817      0.028     -6.413      0.000      -0.237      -0.126
# nonwhite_pct          0.5024      0.024     20.878      0.000       0.455       0.550
# female_pct            0.4300      0.063      6.863      0.000       0.307       0.553
# age29andunder_pct    -0.3782      0.037    -10.262      0.000      -0.450      -0.306
# median_hh_inc        -0.0001   1.98e-05     -7.470      0.000      -0.000      -0.000
# lesshs_pct           -0.1410      0.045     -3.165      0.002      -0.228      -0.054
# lesscollege_pct      -0.6536      0.028    -23.168      0.000      -0.709      -0.598
# rural_pct            -0.0595      0.008     -7.067      0.000      -0.076      -0.043
# ruralurban_cc        -0.5372      0.088     -6.111      0.000      -0.710      -0.365
# ==============================================================================
# Omnibus:                      124.348   Durbin-Watson:                   1.158
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              355.328
# Skew:                           0.120   Prob(JB):                     6.94e-78
# Kurtosis:                       4.637   Cond. No.                     1.15e+06
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 1.15e+06. This might indicate that there are
# strong multicollinearity or other numerical problems.

# %% [markdown]
# Now, HC for ALL the variables. Does this move the $R^2$ from 0.626, which we got with the smaller set of variables?

# %%
y = nation['pctHC'] # dependent varible

x = nation[['white_pct', 'black_pct',
       'hispanic_pct', 'nonwhite_pct', 'foreignborn_pct', 'female_pct',
       'age29andunder_pct', 'age65andolder_pct', 'median_hh_inc',
       'clf_unemploy_pct', 'lesshs_pct', 'lesscollege_pct',
       'lesshs_whites_pct', 'lesscollege_whites_pct', 'rural_pct',
       'ruralurban_cc']]

x = sm.add_constant(x)

model = sm.OLS(y,x).fit()
predictions = model.predict(x)

print(model.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  pctHC   R-squared:                       0.656
# Model:                            OLS   Adj. R-squared:                  0.654
# Method:                 Least Squares   F-statistic:                     369.5
# Date:                Sun, 19 Feb 2023   Prob (F-statistic):               0.00
# Time:                        09:56:13   Log-Likelihood:                -11248.
# No. Observations:                3114   AIC:                         2.253e+04
# Df Residuals:                    3097   BIC:                         2.263e+04
# Df Model:                          16
# Covariance Type:            nonrobust
# ==========================================================================================
#                              coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------------------
# const                     56.1340      5.195     10.806      0.000      45.948      66.320
# white_pct                  0.4979      0.081      6.162      0.000       0.340       0.656
# black_pct                  0.1594      0.026      6.070      0.000       0.108       0.211
# hispanic_pct              -0.1181      0.032     -3.719      0.000      -0.180      -0.056
# nonwhite_pct               0.8403      0.087      9.645      0.000       0.669       1.011
# foreignborn_pct            0.3215      0.054      5.928      0.000       0.215       0.428
# female_pct                 0.2616      0.078      3.365      0.001       0.109       0.414
# age29andunder_pct         -0.6469      0.063    -10.349      0.000      -0.770      -0.524
# age65andolder_pct         -0.4939      0.082     -6.021      0.000      -0.655      -0.333
# median_hh_inc             -0.0002   2.45e-05     -8.238      0.000      -0.000      -0.000
# clf_unemploy_pct           0.7977      0.069     11.502      0.000       0.662       0.934
# lesshs_pct                -0.4514      0.095     -4.740      0.000      -0.638      -0.265
# lesscollege_pct           -0.2792      0.098     -2.848      0.004      -0.471      -0.087
# lesshs_whites_pct          0.0506      0.094      0.539      0.590      -0.134       0.235
# lesscollege_whites_pct    -0.3662      0.083     -4.437      0.000      -0.528      -0.204
# rural_pct                 -0.0412      0.008     -4.933      0.000      -0.058      -0.025
# ruralurban_cc             -0.3280      0.090     -3.642      0.000      -0.505      -0.151
# ==============================================================================
# Omnibus:                      117.735   Durbin-Watson:                   1.242
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              173.255
# Skew:                           0.362   Prob(JB):                     2.39e-38
# Kurtosis:                       3.900   Cond. No.                     1.59e+06
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 1.59e+06. This might indicate that there are
# strong multicollinearity or other numerical problems.

# %% [markdown]
# With all the variables, the $R^2$ increases a bit (to 0.656) but not much. There is still a lot of variation in the voting that these variables don't explain.

# %% [markdown]
# Let's look at the correlation tables for the national data and the IL only data.

# %%
# National Data (including IL)
corr1 = nation[['pctDT', 'pctHC','white_pct', 'black_pct', 'hispanic_pct', 'nonwhite_pct',
       'foreignborn_pct', 'female_pct', 'age29andunder_pct',
       'age65andolder_pct', 'median_hh_inc', 'clf_unemploy_pct', 'lesshs_pct',
       'lesscollege_pct', 'lesshs_whites_pct', 'lesscollege_whites_pct',
       'rural_pct', 'ruralurban_cc']].corr()
corr1.style.background_gradient(cmap='coolwarm',axis=None).format(precision=3)
# Out:
# <style type="text/css">
# #T_ace2d_row0_col0, #T_ace2d_row1_col1, #T_ace2d_row2_col2, #T_ace2d_row3_col3, #T_ace2d_row4_col4, #T_ace2d_row5_col5, #T_ace2d_row6_col6, #T_ace2d_row7_col7, #T_ace2d_row8_col8, #T_ace2d_row9_col9, #T_ace2d_row10_col10, #T_ace2d_row11_col11, #T_ace2d_row12_col12, #T_ace2d_row13_col13, #T_ace2d_row14_col14, #T_ace2d_row15_col15, #T_ace2d_row16_col16, #T_ace2d_row17_col17 {
#   background-color: #b40426;
#   color: #f1f1f1;
# }
# #T_ace2d_row0_col1, #T_ace2d_row1_col0 {
#   background-color: #3c4ec2;
#   color: #f1f1f1;
# }
# #T_ace2d_row0_col2, #T_ace2d_row2_col0 {
#   background-color: #f29274;
#   color: #f1f1f1;
# }
# #T_ace2d_row0_col3, #T_ace2d_row3_col0 {
#   background-color: #9dbdff;
#   color: #000000;
# }
# #T_ace2d_row0_col4, #T_ace2d_row0_col10, #T_ace2d_row4_col0, #T_ace2d_row10_col0 {
#   background-color: #c1d4f4;
#   color: #000000;
# }
# #T_ace2d_row0_col5, #T_ace2d_row5_col0 {
#   background-color: #86a9fc;
#   color: #f1f1f1;
# }
# #T_ace2d_row0_col6, #T_ace2d_row2_col8, #T_ace2d_row6_col0, #T_ace2d_row8_col2 {
#   background-color: #9ebeff;
#   color: #000000;
# }
# #T_ace2d_row0_col7, #T_ace2d_row4_col17, #T_ace2d_row7_col0, #T_ace2d_row7_col12, #T_ace2d_row11_col17, #T_ace2d_row12_col7, #T_ace2d_row17_col4, #T_ace2d_row17_col11 {
#   background-color: #d3dbe7;
#   color: #000000;
# }
# #T_ace2d_row0_col8, #T_ace2d_row8_col0 {
#   background-color: #bad0f8;
#   color: #000000;
# }
# #T_ace2d_row0_col9, #T_ace2d_row1_col11, #T_ace2d_row9_col0, #T_ace2d_row11_col1 {
#   background-color: #f7ba9f;
#   color: #000000;
# }
# #T_ace2d_row0_col11, #T_ace2d_row5_col15, #T_ace2d_row9_col10, #T_ace2d_row10_col9, #T_ace2d_row11_col0, #T_ace2d_row15_col5 {
#   background-color: #b6cefa;
#   color: #000000;
# }
# #T_ace2d_row0_col12, #T_ace2d_row3_col7, #T_ace2d_row3_col13, #T_ace2d_row7_col3, #T_ace2d_row8_col10, #T_ace2d_row10_col8, #T_ace2d_row12_col0, #T_ace2d_row13_col3 {
#   background-color: #e8d6cc;
#   color: #000000;
# }
# #T_ace2d_row0_col13, #T_ace2d_row13_col0 {
#   background-color: #f49a7b;
#   color: #000000;
# }
# #T_ace2d_row0_col14, #T_ace2d_row14_col0, #T_ace2d_row14_col16, #T_ace2d_row16_col14 {
#   background-color: #f7b599;
#   color: #000000;
# }
# #T_ace2d_row0_col15, #T_ace2d_row15_col0 {
#   background-color: #ed8366;
#   color: #f1f1f1;
# }
# #T_ace2d_row0_col16, #T_ace2d_row9_col16, #T_ace2d_row13_col16, #T_ace2d_row16_col0, #T_ace2d_row16_col9, #T_ace2d_row16_col13 {
#   background-color: #f59c7d;
#   color: #000000;
# }
# #T_ace2d_row0_col17, #T_ace2d_row17_col0 {
#   background-color: #f7b194;
#   color: #000000;
# }
# #T_ace2d_row1_col2, #T_ace2d_row2_col1, #T_ace2d_row10_col14, #T_ace2d_row14_col10 {
#   background-color: #7b9ff9;
#   color: #f1f1f1;
# }
# #T_ace2d_row1_col3, #T_ace2d_row3_col1, #T_ace2d_row5_col12, #T_ace2d_row12_col5 {
#   background-color: #f4987a;
#   color: #000000;
# }
# #T_ace2d_row1_col4, #T_ace2d_row4_col1 {
#   background-color: #f0cdbb;
#   color: #000000;
# }
# #T_ace2d_row1_col5, #T_ace2d_row5_col1 {
#   background-color: #ef886b;
#   color: #f1f1f1;
# }
# #T_ace2d_row1_col6, #T_ace2d_row6_col1, #T_ace2d_row13_col17, #T_ace2d_row15_col17, #T_ace2d_row17_col13, #T_ace2d_row17_col15 {
#   background-color: #f7af91;
#   color: #000000;
# }
# #T_ace2d_row1_col7, #T_ace2d_row7_col1 {
#   background-color: #ead5c9;
#   color: #000000;
# }
# #T_ace2d_row1_col8, #T_ace2d_row8_col1, #T_ace2d_row14_col17, #T_ace2d_row17_col14 {
#   background-color: #f2c9b4;
#   color: #000000;
# }
# #T_ace2d_row1_col9, #T_ace2d_row9_col1 {
#   background-color: #aec9fc;
#   color: #000000;
# }
# #T_ace2d_row1_col10, #T_ace2d_row8_col11, #T_ace2d_row10_col1, #T_ace2d_row11_col8 {
#   background-color: #ecd3c5;
#   color: #000000;
# }
# #T_ace2d_row1_col12, #T_ace2d_row4_col13, #T_ace2d_row5_col7, #T_ace2d_row7_col5, #T_ace2d_row7_col15, #T_ace2d_row12_col1, #T_ace2d_row13_col4, #T_ace2d_row15_col7 {
#   background-color: #dcdddd;
#   color: #000000;
# }
# #T_ace2d_row1_col13, #T_ace2d_row13_col1 {
#   background-color: #98b9ff;
#   color: #000000;
# }
# #T_ace2d_row1_col14, #T_ace2d_row14_col1 {
#   background-color: #b5cdfa;
#   color: #000000;
# }
# #T_ace2d_row1_col15, #T_ace2d_row15_col1 {
#   background-color: #82a6fb;
#   color: #f1f1f1;
# }
# #T_ace2d_row1_col16, #T_ace2d_row16_col1 {
#   background-color: #92b4fe;
#   color: #000000;
# }
# #T_ace2d_row1_col17, #T_ace2d_row17_col1 {
#   background-color: #a2c1ff;
#   color: #000000;
# }
# #T_ace2d_row2_col3, #T_ace2d_row3_col2 {
#   background-color: #779af7;
#   color: #f1f1f1;
# }
# #T_ace2d_row2_col4, #T_ace2d_row4_col2 {
#   background-color: #799cf8;
#   color: #f1f1f1;
# }
# #T_ace2d_row2_col5, #T_ace2d_row5_col2 {
#   background-color: #3b4cc0;
#   color: #f1f1f1;
# }
# #T_ace2d_row2_col6, #T_ace2d_row6_col2 {
#   background-color: #88abfd;
#   color: #000000;
# }
# #T_ace2d_row2_col7, #T_ace2d_row7_col2, #T_ace2d_row7_col10, #T_ace2d_row10_col7 {
#   background-color: #e6d7cf;
#   color: #000000;
# }
# #T_ace2d_row2_col9, #T_ace2d_row9_col2 {
#   background-color: #f7ad90;
#   color: #000000;
# }
# #T_ace2d_row2_col10, #T_ace2d_row10_col2 {
#   background-color: #edd2c3;
#   color: #000000;
# }
# #T_ace2d_row2_col11, #T_ace2d_row11_col2 {
#   background-color: #9abbff;
#   color: #000000;
# }
# #T_ace2d_row2_col12, #T_ace2d_row6_col15, #T_ace2d_row12_col2, #T_ace2d_row15_col6 {
#   background-color: #8caffe;
#   color: #000000;
# }
# #T_ace2d_row2_col13, #T_ace2d_row13_col2 {
#   background-color: #dfdbd9;
#   color: #000000;
# }
# #T_ace2d_row2_col14, #T_ace2d_row14_col2 {
#   background-color: #e1dad6;
#   color: #000000;
# }
# #T_ace2d_row2_col15, #T_ace2d_row15_col2 {
#   background-color: #f5c0a7;
#   color: #000000;
# }
# #T_ace2d_row2_col16, #T_ace2d_row4_col8, #T_ace2d_row6_col8, #T_ace2d_row8_col4, #T_ace2d_row8_col6, #T_ace2d_row9_col15, #T_ace2d_row15_col9, #T_ace2d_row16_col2 {
#   background-color: #f7bca1;
#   color: #000000;
# }
# #T_ace2d_row2_col17, #T_ace2d_row3_col8, #T_ace2d_row8_col3, #T_ace2d_row8_col12, #T_ace2d_row12_col8, #T_ace2d_row12_col17, #T_ace2d_row17_col2, #T_ace2d_row17_col12 {
#   background-color: #efcfbf;
#   color: #000000;
# }
# #T_ace2d_row3_col4, #T_ace2d_row4_col3 {
#   background-color: #ccd9ed;
#   color: #000000;
# }
# #T_ace2d_row3_col5, #T_ace2d_row5_col3 {
#   background-color: #ec7f63;
#   color: #f1f1f1;
# }
# #T_ace2d_row3_col6, #T_ace2d_row6_col3, #T_ace2d_row6_col7, #T_ace2d_row7_col6 {
#   background-color: #dadce0;
#   color: #000000;
# }
# #T_ace2d_row3_col9, #T_ace2d_row8_col15, #T_ace2d_row9_col3, #T_ace2d_row15_col8 {
#   background-color: #bed2f6;
#   color: #000000;
# }
# #T_ace2d_row3_col10, #T_ace2d_row10_col3 {
#   background-color: #b3cdfb;
#   color: #000000;
# }
# #T_ace2d_row3_col11, #T_ace2d_row11_col3 {
#   background-color: #f59f80;
#   color: #000000;
# }
# #T_ace2d_row3_col12, #T_ace2d_row6_col10, #T_ace2d_row10_col6, #T_ace2d_row12_col3 {
#   background-color: #f7b79b;
#   color: #000000;
# }
# #T_ace2d_row3_col14, #T_ace2d_row14_col3 {
#   background-color: #f2cbb7;
#   color: #000000;
# }
# #T_ace2d_row3_col15, #T_ace2d_row5_col14, #T_ace2d_row14_col5, #T_ace2d_row15_col3 {
#   background-color: #d8dce2;
#   color: #000000;
# }
# #T_ace2d_row3_col16, #T_ace2d_row4_col7, #T_ace2d_row7_col4, #T_ace2d_row8_col13, #T_ace2d_row13_col8, #T_ace2d_row16_col3 {
#   background-color: #cdd9ec;
#   color: #000000;
# }
# #T_ace2d_row3_col17, #T_ace2d_row17_col3 {
#   background-color: #cad8ef;
#   color: #000000;
# }
# #T_ace2d_row4_col5, #T_ace2d_row5_col4 {
#   background-color: #ec8165;
#   color: #f1f1f1;
# }
# #T_ace2d_row4_col6, #T_ace2d_row6_col4 {
#   background-color: #e57058;
#   color: #f1f1f1;
# }
# #T_ace2d_row4_col9, #T_ace2d_row9_col4 {
#   background-color: #bbd1f8;
#   color: #000000;
# }
# #T_ace2d_row4_col10, #T_ace2d_row10_col4 {
#   background-color: #e2dad5;
#   color: #000000;
# }
# #T_ace2d_row4_col11, #T_ace2d_row11_col4 {
#   background-color: #e0dbd8;
#   color: #000000;
# }
# #T_ace2d_row4_col12, #T_ace2d_row12_col4 {
#   background-color: #f7aa8c;
#   color: #000000;
# }
# #T_ace2d_row4_col14, #T_ace2d_row5_col17, #T_ace2d_row7_col17, #T_ace2d_row14_col4, #T_ace2d_row17_col5, #T_ace2d_row17_col7 {
#   background-color: #c5d6f2;
#   color: #000000;
# }
# #T_ace2d_row4_col15, #T_ace2d_row15_col4 {
#   background-color: #bcd2f7;
#   color: #000000;
# }
# #T_ace2d_row4_col16, #T_ace2d_row8_col17, #T_ace2d_row16_col4, #T_ace2d_row17_col8 {

# %%
# Illinois Only
corr1 = df[['PctDT', 'PctHC','white_pct', 'black_pct', 'hispanic_pct', 'nonwhite_pct',
       'foreignborn_pct', 'female_pct', 'age29andunder_pct',
       'age65andolder_pct', 'median_hh_inc', 'clf_unemploy_pct', 'lesshs_pct',
       'lesscollege_pct', 'lesshs_whites_pct', 'lesscollege_whites_pct',
       'rural_pct', 'ruralurban_cc']].corr()
corr1.style.background_gradient(cmap='coolwarm',axis=None).format(precision=3)
# Out:
# <style type="text/css">
# #T_42910_row0_col0, #T_42910_row1_col1, #T_42910_row2_col2, #T_42910_row3_col3, #T_42910_row4_col4, #T_42910_row5_col5, #T_42910_row6_col6, #T_42910_row7_col7, #T_42910_row8_col8, #T_42910_row9_col9, #T_42910_row10_col10, #T_42910_row11_col11, #T_42910_row12_col12, #T_42910_row13_col13, #T_42910_row14_col14, #T_42910_row15_col15, #T_42910_row16_col16, #T_42910_row17_col17 {
#   background-color: #b40426;
#   color: #f1f1f1;
# }
# #T_42910_row0_col1, #T_42910_row1_col0, #T_42910_row2_col5, #T_42910_row5_col2 {
#   background-color: #3b4cc0;
#   color: #f1f1f1;
# }
# #T_42910_row0_col2, #T_42910_row2_col0, #T_42910_row9_col16, #T_42910_row16_col9 {
#   background-color: #dd5f4b;
#   color: #f1f1f1;
# }
# #T_42910_row0_col3, #T_42910_row3_col0 {
#   background-color: #97b8ff;
#   color: #000000;
# }
# #T_42910_row0_col4, #T_42910_row1_col16, #T_42910_row4_col0, #T_42910_row8_col16, #T_42910_row16_col1, #T_42910_row16_col8 {
#   background-color: #6f92f3;
#   color: #f1f1f1;
# }
# #T_42910_row0_col5, #T_42910_row0_col6, #T_42910_row5_col0, #T_42910_row6_col0 {
#   background-color: #6180e9;
#   color: #f1f1f1;
# }
# #T_42910_row0_col7, #T_42910_row2_col11, #T_42910_row5_col14, #T_42910_row7_col0, #T_42910_row7_col13, #T_42910_row11_col2, #T_42910_row13_col7, #T_42910_row14_col5 {
#   background-color: #bad0f8;
#   color: #000000;
# }
# #T_42910_row0_col8, #T_42910_row8_col0 {
#   background-color: #82a6fb;
#   color: #f1f1f1;
# }
# #T_42910_row0_col9, #T_42910_row1_col8, #T_42910_row8_col1, #T_42910_row9_col0 {
#   background-color: #f18f71;
#   color: #f1f1f1;
# }
# #T_42910_row0_col10, #T_42910_row10_col0 {
#   background-color: #9dbdff;
#   color: #000000;
# }
# #T_42910_row0_col11, #T_42910_row11_col0 {
#   background-color: #d1dae9;
#   color: #000000;
# }
# #T_42910_row0_col12, #T_42910_row12_col0 {
#   background-color: #f3c7b1;
#   color: #000000;
# }
# #T_42910_row0_col13, #T_42910_row13_col0 {
#   background-color: #e36b54;
#   color: #f1f1f1;
# }
# #T_42910_row0_col14, #T_42910_row4_col10, #T_42910_row6_col8, #T_42910_row8_col6, #T_42910_row9_col17, #T_42910_row10_col4, #T_42910_row14_col0, #T_42910_row17_col9 {
#   background-color: #f39475;
#   color: #000000;
# }
# #T_42910_row0_col15, #T_42910_row15_col0 {
#   background-color: #de614d;
#   color: #f1f1f1;
# }
# #T_42910_row0_col16, #T_42910_row13_col16, #T_42910_row16_col0, #T_42910_row16_col13 {
#   background-color: #e7745b;
#   color: #f1f1f1;
# }
# #T_42910_row0_col17, #T_42910_row2_col9, #T_42910_row9_col2, #T_42910_row17_col0 {
#   background-color: #ea7b60;
#   color: #f1f1f1;
# }
# #T_42910_row1_col2, #T_42910_row2_col1, #T_42910_row2_col3, #T_42910_row3_col2 {
#   background-color: #5a78e4;
#   color: #f1f1f1;
# }
# #T_42910_row1_col3, #T_42910_row3_col1 {
#   background-color: #f59c7d;
#   color: #000000;
# }
# #T_42910_row1_col4, #T_42910_row4_col1, #T_42910_row9_col13, #T_42910_row13_col9 {
#   background-color: #e57058;
#   color: #f1f1f1;
# }
# #T_42910_row1_col5, #T_42910_row3_col5, #T_42910_row5_col1, #T_42910_row5_col3, #T_42910_row12_col14, #T_42910_row14_col12 {
#   background-color: #d75445;
#   color: #f1f1f1;
# }
# #T_42910_row1_col6, #T_42910_row5_col6, #T_42910_row6_col1, #T_42910_row6_col5 {
#   background-color: #dc5d4a;
#   color: #f1f1f1;
# }
# #T_42910_row1_col7, #T_42910_row3_col6, #T_42910_row6_col3, #T_42910_row7_col1 {
#   background-color: #f4c5ad;
#   color: #000000;
# }
# #T_42910_row1_col9, #T_42910_row9_col1 {
#   background-color: #84a7fc;
#   color: #f1f1f1;
# }
# #T_42910_row1_col10, #T_42910_row10_col1, #T_42910_row11_col14, #T_42910_row14_col11 {
#   background-color: #f7b093;
#   color: #000000;
# }
# #T_42910_row1_col11, #T_42910_row11_col1 {
#   background-color: #ecd3c5;
#   color: #000000;
# }
# #T_42910_row1_col12, #T_42910_row3_col10, #T_42910_row10_col3, #T_42910_row12_col1 {
#   background-color: #c3d5f4;
#   color: #000000;
# }
# #T_42910_row1_col13, #T_42910_row13_col1 {
#   background-color: #6c8ff1;
#   color: #f1f1f1;
# }
# #T_42910_row1_col14, #T_42910_row14_col1 {
#   background-color: #8fb1fe;
#   color: #000000;
# }
# #T_42910_row1_col15, #T_42910_row10_col14, #T_42910_row14_col10, #T_42910_row15_col1 {
#   background-color: #6485ec;
#   color: #f1f1f1;
# }
# #T_42910_row1_col17, #T_42910_row6_col16, #T_42910_row16_col6, #T_42910_row17_col1 {
#   background-color: #779af7;
#   color: #f1f1f1;
# }
# #T_42910_row2_col4, #T_42910_row4_col2 {
#   background-color: #6687ed;
#   color: #f1f1f1;
# }
# #T_42910_row2_col6, #T_42910_row6_col2 {
#   background-color: #5f7fe8;
#   color: #f1f1f1;
# }
# #T_42910_row2_col7, #T_42910_row7_col2 {
#   background-color: #e0dbd8;
#   color: #000000;
# }
# #T_42910_row2_col8, #T_42910_row8_col2 {
#   background-color: #86a9fc;
#   color: #f1f1f1;
# }
# #T_42910_row2_col10, #T_42910_row2_col12, #T_42910_row10_col2, #T_42910_row12_col2 {
#   background-color: #bcd2f7;
#   color: #000000;
# }
# #T_42910_row2_col13, #T_42910_row13_col2 {
#   background-color: #f59d7e;
#   color: #000000;
# }
# #T_42910_row2_col14, #T_42910_row5_col11, #T_42910_row11_col5, #T_42910_row14_col2 {
#   background-color: #f4c6af;
#   color: #000000;
# }
# #T_42910_row2_col15, #T_42910_row15_col2 {
#   background-color: #ef886b;
#   color: #f1f1f1;
# }
# #T_42910_row2_col16, #T_42910_row16_col2, #T_42910_row16_col17, #T_42910_row17_col16 {
#   background-color: #eb7d62;
#   color: #f1f1f1;
# }
# #T_42910_row2_col17, #T_42910_row4_col8, #T_42910_row8_col4, #T_42910_row17_col2 {
#   background-color: #f7a889;
#   color: #000000;
# }
# #T_42910_row3_col4, #T_42910_row4_col3, #T_42910_row11_col13, #T_42910_row12_col16, #T_42910_row13_col11, #T_42910_row16_col12 {
#   background-color: #f1ccb8;
#   color: #000000;
# }
# #T_42910_row3_col7, #T_42910_row7_col3 {
#   background-color: #c6d6f1;
#   color: #000000;
# }
# #T_42910_row3_col8, #T_42910_row8_col3 {
#   background-color: #f7b99e;
#   color: #000000;
# }
# #T_42910_row3_col9, #T_42910_row3_col16, #T_42910_row9_col3, #T_42910_row16_col3 {
#   background-color: #a6c4fe;
#   color: #000000;
# }
# #T_42910_row3_col11, #T_42910_row11_col3 {
#   background-color: #f7ba9f;
#   color: #000000;
# }
# #T_42910_row3_col12, #T_42910_row12_col3 {
#   background-color: #f7b396;
#   color: #000000;
# }
# #T_42910_row3_col13, #T_42910_row13_col3 {
#   background-color: #cad8ef;
#   color: #000000;
# }
# #T_42910_row3_col14, #T_42910_row14_col3 {
#   background-color: #e9d5cb;
#   color: #000000;
# }
# #T_42910_row3_col15, #T_42910_row15_col3 {
#   background-color: #bfd3f6;
#   color: #000000;
# }
# #T_42910_row3_col17, #T_42910_row17_col3 {
#   background-color: #c1d4f4;
#   color: #000000;
# }
# #T_42910_row4_col5, #T_42910_row5_col4 {
#   background-color: #e16751;
#   color: #f1f1f1;
# }
# #T_42910_row4_col6, #T_42910_row6_col4 {
#   background-color: #c53334;
#   color: #f1f1f1;
# }
# #T_42910_row4_col7, #T_42910_row7_col4, #T_42910_row7_col10, #T_42910_row10_col7 {
#   background-color: #e4d9d2;
#   color: #000000;
# }
# #T_42910_row4_col9, #T_42910_row9_col4 {
#   background-color: #7da0f9;
#   color: #f1f1f1;
# }
# #T_42910_row4_col11, #T_42910_row9_col11, #T_42910_row11_col4, #T_42910_row11_col9 {
#   background-color: #e1dad6;
#   color: #000000;
# }
# #T_42910_row4_col12, #T_42910_row11_col17, #T_42910_row12_col4, #T_42910_row17_col11 {
#   background-color: #e7d7ce;
#   color: #000000;
# }
# #T_42910_row4_col13, #T_42910_row5_col13, #T_42910_row13_col4, #T_42910_row13_col5 {
#   background-color: #90b2fe;
#   color: #000000;
# }
# #T_42910_row4_col14, #T_42910_row8_col14, #T_42910_row14_col4, #T_42910_row14_col8 {
#   background-color: #9bbcff;
#   color: #000000;
# }
# #T_42910_row4_col15, #T_42910_row5_col15, #T_42910_row15_col4, #T_42910_row15_col5 {
#   background-color: #7ea1fa;
#   color: #f1f1f1;
# }
# #T_42910_row4_col16, #T_42910_row10_col17, #T_42910_row16_col4, #T_42910_row17_col10 {
#   background-color: #81a4fb;
#   color: #f1f1f1;
# }
# #T_42910_row4_col17, #T_42910_row17_col4 {
#   background-color: #98b9ff;
#   color: #000000;
# }
# #T_42910_row5_col7, #T_42910_row7_col5 {
#   background-color: #d9dce1;
#   color: #000000;
# }
# #T_42910_row5_col8, #T_42910_row8_col5 {
#   background-color: #f29274;
#   color: #f1f1f1;
# }
# #T_42910_row5_col9, #T_42910_row6_col9, #T_42910_row9_col5, #T_42910_row9_col6, #T_42910_row10_col13, #T_42910_row13_col10 {
#   background-color: #7597f6;
#   color: #f1f1f1;
# }
# #T_42910_row5_col10, #T_42910_row5_col12, #T

# %% [markdown]
# After typing all the stuff below, I found a simple explaination here: https://medium.com/swlh/interpreting-linear-regression-through-statsmodels-summary-4796d359035a
#
# ### Durbin-Watson statistic.
# https://www.statsmodels.org/stable/generated/statsmodels.stats.stattools.durbin_watson.html#statsmodels.stats.stattools.durbin_watson
# * The null hypothesis of the test is that there is no serial correlation in the residuals.
# * The test statistic is approximately equal to 2*(1-r) where r is the sample autocorrelation of the residuals. Thus, for r == 0, indicating no serial correlation, the test statistic equals 2. This statistic will always be between 0 and 4. The closer to 0 the statistic, the more evidence for positive serial correlation. The closer to 4, the more evidence for negative serial correlation.
#
# ### Omnibus test for normality. (= _Chi_^2 test)
#
#
# ### kurtosis measures
# https://www.simplypsychology.org/kurtosis.html
# * Kurtosis is a statistical measure used to describe the degree to which scores cluster in the tails or the peak of a frequency distribution. The peak is the tallest part of the distribution, and the tails are the ends of the distribution.
#
# * There are three types of kurtosis: mesokurtic, leptokurtic, and platykurtic.
#  * When kurtosis is equal to 3, the distribution is mesokurtic. This means the kurtosis is the same as the normal distribution, it is mesokurtic (medium peak). The kurtosis of a mesokurtic distribution is neither high nor low, rather it is considered to be a baseline for the two other classifications.
#  * Positive excess values of kurtosis (>3) indicate that a distribution is peaked and possess thick tails. Leptokurtic distributions have positive kurtosis values. A leptokurtic distribution has a higher peak (thin bell) and taller (i.e. fatter and heavy) tails than a normal distribution.
#  * Negative excess values of kurtosis (<3) indicate that a distribution is flat and has thin tails.
#  * Platykurtic distributions have negative kurtosis values. A platykurtic distribution is flatter (less peaked) when compared with the normal distribution, with fewer values in its shorter (i.e. lighter and thinner) tails.
#
# ### Skewness.
# https://www.statisticshowto.com/probability-and-statistics/descriptive-statistics/skewness/
# * Skewness is a measure of symmetry in a distribution. Actually, it’s more correct to describe it as a measure of lack of symmetry. A standard normal distribution is perfectly symmetrical and has zero skew.
#  * A symmetrical distribution has a skew of zero.
#  * A positive result means that your data is positively skewed. (That is, right-tail.)
#  * A negative results means that your data is negatively skewed. (Left-tail.)
#
# ### Jarque-Bera test of normality.
# https://www.statsmodels.org/stable/generated/statsmodels.stats.stattools.jarque_bera.html#statsmodels.stats.stattools.jarque_bera
# https://en.wikipedia.org/wiki/Jarque%E2%80%93Bera_test
# * The Jarque–Bera test is a goodness-of-fit test of whether sample data have the skewness and kurtosis matching a normal distribution. Samples from a normal distribution have an expected skewness of 0 and an expected excess kurtosis of 0 (which is the same as a kurtosis of 3).
# *

# %%
# let's explore how the different states generate different values . . .

states = nation['state'].value_counts()

# %%
states.index
# Out:
# Index(['Texas', 'Georgia', 'Virginia', 'Kentucky', 'Missouri', 'Kansas',
#        'Illinois', 'North Carolina', 'Iowa', 'Tennessee', 'Nebraska',
#        'Indiana', 'Ohio', 'Minnesota', 'Michigan', 'Mississippi', 'Oklahoma',
#        'Arkansas', 'Wisconsin', 'Alabama', 'Pennsylvania', 'Florida',
#        'South Dakota', 'Colorado', 'Louisiana', 'New York', 'California',
#        'Montana', 'West Virginia', 'North Dakota', 'South Carolina', 'Idaho',
#        'Washington', 'Oregon', 'New Mexico', 'Utah', 'Maryland', 'Wyoming',
#        'New Jersey', 'Nevada', 'Maine', 'Arizona', 'Vermont', 'Massachusetts',
#        'New Hampshire', 'Connecticut', 'Rhode Island', 'Hawaii', 'Delaware',
#        'District of Columbia'],
#       dtype='object')

# %%
y = nation['pctHC'] # dependent varible

x = nation[['white_pct', 'black_pct',
       'hispanic_pct', 'female_pct',
       'age29andunder_pct', 'age65andolder_pct', 'median_hh_inc',
       'clf_unemploy_pct', 'lesshs_pct', 'lesscollege_pct',
        'rural_pct']]

x = sm.add_constant(x)

model = sm.OLS(y,x).fit()
predictions = model.predict(x)

print(model.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  pctHC   R-squared:                       0.633
# Model:                            OLS   Adj. R-squared:                  0.632
# Method:                 Least Squares   F-statistic:                     486.9
# Date:                Sun, 19 Feb 2023   Prob (F-statistic):               0.00
# Time:                        09:57:11   Log-Likelihood:                -11349.
# No. Observations:                3114   AIC:                         2.272e+04
# Df Residuals:                    3102   BIC:                         2.279e+04
# Df Model:                          11
# Covariance Type:            nonrobust
# =====================================================================================
#                         coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------------
# const                93.7878      4.202     22.319      0.000      85.549     102.027
# white_pct            -0.3214      0.024    -13.535      0.000      -0.368      -0.275
# black_pct             0.2218      0.025      8.832      0.000       0.173       0.271
# hispanic_pct          0.0103      0.029      0.360      0.719      -0.046       0.066
# female_pct            0.6443      0.073      8.877      0.000       0.502       0.787
# age29andunder_pct    -0.4200      0.056     -7.523      0.000      -0.529      -0.311
# age65andolder_pct    -0.2408      0.076     -3.182      0.001      -0.389      -0.092
# median_hh_inc     -3.823e-05   2.07e-05     -1.845      0.065   -7.89e-05     2.4e-06
# clf_unemploy_pct      0.9368      0.069     13.601      0.000       0.802       1.072
# lesshs_pct           -0.2829      0.046     -6.120      0.000      -0.373      -0.192
# lesscollege_pct      -0.6189      0.029    -21.530      0.000      -0.675      -0.563
# rural_pct            -0.0603      0.007     -8.144      0.000      -0.075      -0.046
# ==============================================================================
# Omnibus:                      248.859   Durbin-Watson:                   1.262
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             1452.373
# Skew:                           0.026   Prob(JB):                         0.00
# Kurtosis:                       6.345   Cond. No.                     1.25e+06
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 1.25e+06. This might indicate that there are
# strong multicollinearity or other numerical problems.

# %%
y = nation['pctDT'] # dependent varible

x = nation[['white_pct', 'black_pct',
       'hispanic_pct', 'female_pct',
       'age29andunder_pct', 'age65andolder_pct', 'median_hh_inc',
       'clf_unemploy_pct', 'lesshs_pct', 'lesscollege_pct',
        'rural_pct']]

x = sm.add_constant(x)

model = sm.OLS(y,x).fit()
predictions = model.predict(x)

print(model.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  pctDT   R-squared:                       0.615
# Model:                            OLS   Adj. R-squared:                  0.614
# Method:                 Least Squares   F-statistic:                     450.7
# Date:                Fri, 17 Feb 2023   Prob (F-statistic):               0.00
# Time:                        16:37:31   Log-Likelihood:                -11521.
# No. Observations:                3114   AIC:                         2.307e+04
# Df Residuals:                    3102   BIC:                         2.314e+04
# Df Model:                          11
# Covariance Type:            nonrobust
# =====================================================================================
#                         coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------------
# const               -23.1597      4.441     -5.216      0.000     -31.866     -14.453
# white_pct             0.3586      0.025     14.288      0.000       0.309       0.408
# black_pct            -0.1210      0.027     -4.561      0.000      -0.173      -0.069
# hispanic_pct         -0.0106      0.030     -0.349      0.727      -0.070       0.049
# female_pct           -0.4335      0.077     -5.652      0.000      -0.584      -0.283
# age29andunder_pct     0.3731      0.059      6.323      0.000       0.257       0.489
# age65andolder_pct     0.3214      0.080      4.020      0.000       0.165       0.478
# median_hh_inc      8.936e-05   2.19e-05      4.081      0.000    4.64e-05       0.000
# clf_unemploy_pct     -0.9633      0.073    -13.235      0.000      -1.106      -0.821
# lesshs_pct            0.5238      0.049     10.726      0.000       0.428       0.620
# lesscollege_pct       0.6729      0.030     22.151      0.000       0.613       0.732
# rural_pct             0.0637      0.008      8.133      0.000       0.048       0.079
# ==============================================================================
# Omnibus:                       39.861   Durbin-Watson:                   1.218
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               41.706
# Skew:                          -0.260   Prob(JB):                     8.78e-10
# Kurtosis:                       3.225   Cond. No.                     1.25e+06
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 1.25e+06. This might indicate that there are
# strong multicollinearity or other numerical problems.

# %%
model.rsquared
# Out:
# 0.6151194204842272

# %%
model.params
# Out:
# const               -23.159663
# white_pct             0.358576
# black_pct            -0.121019
# hispanic_pct         -0.010571
# female_pct           -0.433512
# age29andunder_pct     0.373050
# age65andolder_pct     0.321412
# median_hh_inc         0.000089
# clf_unemploy_pct     -0.963269
# lesshs_pct            0.523850
# lesscollege_pct       0.672927
# rural_pct             0.063668
# dtype: float64

# %%
state_rsquare = {}

for s in states.index:
    subset = nation[nation['state'] == s]
    if len(subset) < 15:
        print(f"Model cannot run because {s} has only {len(subset)} counties.")
        #state_rsquare[s] = -999
    else:

        y = subset['pctHC'] # dependent varible

        x = subset[['white_pct', 'black_pct',
        'hispanic_pct', 'female_pct',
        'age29andunder_pct', 'age65andolder_pct', 'median_hh_inc',
        'clf_unemploy_pct', 'lesshs_pct', 'lesscollege_pct',
            'rural_pct']]

        x = sm.add_constant(x)

        model = sm.OLS(y,x).fit()

        state_rsquare[s] = [len(subset),model.rsquared,model.params]
# Out:
# Model cannot run because Vermont has only 14 counties.
# Model cannot run because Massachusetts has only 14 counties.
# Model cannot run because New Hampshire has only 10 counties.
# Model cannot run because Connecticut has only 8 counties.
# Model cannot run because Rhode Island has only 5 counties.
# Model cannot run because Hawaii has only 4 counties.
# Model cannot run because Delaware has only 3 counties.
# Model cannot run because District of Columbia has only 1 counties.

# %%
state_rsquare['Illinois']
# Out:
# [102,
#  0.830272049778888,
#  const                51.394324
#  white_pct            -0.276477
#  black_pct             0.463932
#  hispanic_pct          0.824694
#  female_pct            0.336087
#  age29andunder_pct     0.123948
#  age65andolder_pct     1.158618
#  median_hh_inc        -0.000023
#  clf_unemploy_pct      0.392038
#  lesshs_pct           -0.794643
#  lesscollege_pct      -0.432280
#  rural_pct            -0.052297
#  dtype: float64]

# %% [markdown]
# So this is what my dictionary looks like: key = state name; value = list of numbers (n counties, $r^2$, then regression values).
#
# How do I access these? Let's mess around a bit and make sure I've got the syntax correct.

# %%
state_rsquare['Texas'][1]
# Out:
# 0.8013710695434562

# %%
from heapq import nlargest

res = nlargest(10, state_rsquare, key = lambda state_rsquare : state_rsquare[1] )

print(f"{'State':<14}{'N counties':>10}{'R-squared':>10}{'white':>10}{'black':>10}{'hispanic':>10}{'female':>10}{'<29YO':>10}{'>65YO':>10}{'hh_inc':>10}{'unemploy':>10}{'<hs':>10}{'<college':>10}{'rural':>10}")

for item in res:    
    coef_str = ''
    for i in range(1,12):
        coef_str += f"{state_rsquare[item][2][i]:10.3}"
    print(f"{str(item):<15}{state_rsquare[item][0]:10}{state_rsquare[item][1]:10.5}{coef_str}")
# Out:
# State         N counties R-squared     white     black  hispanic    female     <29YO     >65YO    hh_inc  unemploy       <hs  <college     rural
# Wyoming                23   0.95561    -0.586   0.00884     0.122     -0.28     -1.01     -1.31 -0.000278      0.12    -0.189     -1.05 -0.000812
# Utah                   29   0.93528    -0.746      1.61   -0.0842    -0.714     -2.25      -2.2 -0.000227      0.61    -0.655    -0.536   -0.0613
# Arkansas               75   0.89698    -0.723    -0.135    -0.714 -0.000972    -0.282   -0.0548 -0.000108     0.108     0.498    -0.672   -0.0415
# Oregon                 36   0.86981    -0.703     -1.68     0.151      3.65     -2.13     -2.57 -0.000681      -1.0    -0.498     -1.02    -0.109
# Arizona                15   0.94482     -1.17     -5.77    -0.681      -9.3     -5.65     -5.04  -0.00187     -2.75      2.34     -2.97    -0.441
# North Carolina        100   0.92779    -0.296     0.493    -0.143    0.0629    -0.149    -0.275 -0.000464    -0.355  -0.00166     -1.07    0.0288
# Iowa                   99    0.5976     -1.16     0.606     -1.21      1.55   -0.0946    -0.684 -2.33e-05     0.507    -0.539    0.0107   -0.0237
# South Dakota           66   0.75965    -0.326     0.979     0.607    -0.601     0.457     0.266  6.25e-05     0.237    0.0226    -0.397     -0.03
# Colorado               64   0.92624    -0.553    -0.408     0.114      0.29     -1.27     -1.48 -0.000497   -0.0412    0.0714      -1.3   -0.0541
# Louisiana              64   0.96775    -0.617     0.407     0.172      1.15    -0.899     -1.26   5.1e-05     0.059      0.25    -0.296      0.03

# %% [markdown]
# The `.nlargest()` function isn't working propertly. I'm trying to sort on the $R^2$ values and get the top (and bottom) ten. Iowa shouldn't be listed (0.59) here. And the results are not actually sorted in top-to-bottom order anyway!
#
# Let's try just sorting the results.

# %%
results = sorted(state_rsquare.items(), key = lambda x : x[1][1], reverse= True)[:10] # state
#for item in results:
#    print(item,state_rsquare[item][1])

# %%
type(results)
# Out:
# list

# %%
results[0]
# Out:
# ('Nevada',
#  [17, 0.9886893408675105, const                193.615892
#   white_pct             -0.420362
#   black_pct              0.019346
#   hispanic_pct           0.591271
#   female_pct             0.515286
#   age29andunder_pct     -1.592152
#   age65andolder_pct     -0.726917
#   median_hh_inc         -0.000142
#   clf_unemploy_pct       0.859871
#   lesshs_pct             0.451775
#   lesscollege_pct       -1.295604
#   rural_pct             -0.041053
#   dtype: float64])

# %%
for item in results[0:2]:
    print(item[1][1]) # r values
# Out:
# 0.9886893408675105
# 0.9781048298066375

# %%
for item in results[0:2]:
    print(item[1][2]) # interesting -- the regression figures are a list of values, so we'll extract them by going item[1][2][x]
# Out:
# const                193.615892
# white_pct             -0.420362
# black_pct              0.019346
# hispanic_pct           0.591271
# female_pct             0.515286
# age29andunder_pct     -1.592152
# age65andolder_pct     -0.726917
# median_hh_inc         -0.000142
# clf_unemploy_pct       0.859871
# lesshs_pct             0.451775
# lesscollege_pct       -1.295604
# rural_pct             -0.041053
# dtype: float64
# const                93.717956
# white_pct            -0.674736
# black_pct             0.199012
# hispanic_pct         -0.290176
# female_pct            0.611941
# age29andunder_pct    -0.284620
# age65andolder_pct    -0.341180
# median_hh_inc        -0.000203
# clf_unemploy_pct     -0.123606
# lesshs_pct            0.186307
# lesscollege_pct      -0.351290
# rural_pct            -0.012090
# dtype: float64

# %%
results = sorted(state_rsquare.items(), key = lambda x : x[1][1], reverse= True)[:10]

print(f"{'State':<15}{'N counties':>10}{'R-squared':>10}{'white':>10}{'black':>10}{'hispanic':>10}{'female':>10}{'<29YO':>10}{'>65YO':>10}{'hh_inc':>10}{'unemploy':>10}{'<hs':>10}{'<college':>10}{'rural':>10}")

for item in results:
    state = item[0]
    counties = item[1][0] # N counties
    r_squared = item[1][1] 
    coef_str = ''
    for i in range(1,12):
        coef_str += f"{item[1][2][i]:10.3}"
    print(f"{str(state):<15}{counties:10}{r_squared:10.3}{coef_str}")
# Out:
# State          N counties R-squared     white     black  hispanic    female     <29YO     >65YO    hh_inc  unemploy       <hs  <college     rural
# Nevada                 17     0.989     -0.42    0.0193     0.591     0.515     -1.59    -0.727 -0.000142      0.86     0.452      -1.3   -0.0411
# Alabama                67     0.978    -0.675     0.199     -0.29     0.612    -0.285    -0.341 -0.000203    -0.124     0.186    -0.351   -0.0121
# Mississippi            82     0.976   -0.0857      0.84     0.643    -0.207     0.761     0.977  0.000128   0.00536     0.112    -0.165   0.00575
# South Carolina         46     0.971    -0.884   -0.0477     -0.58    -0.256   -0.0932    -0.197 -0.000319   -0.0511    -0.387    -0.374   -0.0206
# Maryland               24      0.97    -0.217     0.584     0.722     0.633    -0.157    -0.194 -7.95e-05     0.505    -0.432    -0.626   0.00802
# Louisiana              64     0.968    -0.617     0.407     0.172      1.15    -0.899     -1.26   5.1e-05     0.059      0.25    -0.296      0.03
# Maine                  16     0.961     0.924    -0.946      6.27     -2.52     -1.04    -0.559 -0.000321     -1.13     0.178    -0.946     -0.15
# New Jersey             21     0.958    -0.248     0.684    0.0278     -1.04    -0.209      -1.3 -0.000607     -1.89    -0.701    -0.663   -0.0518
# Wyoming                23     0.956    -0.586   0.00884     0.122     -0.28     -1.01     -1.31 -0.000278      0.12    -0.189     -1.05 -0.000812
# Arizona                15     0.945     -1.17     -5.77    -0.681      -9.3     -5.65     -5.04  -0.00187     -2.75      2.34     -2.97    -0.441

# %%
results = sorted(state_rsquare.items(), key = lambda x : x[1][1], reverse= True)[-10:]

print(f"{'State':<15}{'N counties':>10}{'R-squared':>10}{'white':>10}{'black':>10}{'hispanic':>10}{'female':>10}{'<29YO':>10}{'>65YO':>10}{'hh_inc':>10}{'unemploy':>10}{'<hs':>10}{'<college':>10}{'rural':>10}")

for item in results:
    state = item[0]
    counties = item[1][0] # N counties
    r_squared = item[1][1] 
    coef_str = ''
    for i in range(1,12):
        coef_str += f"{item[1][2][i]:10.3}"
    print(f"{str(state):<15}{counties:10}{r_squared:10.3}{coef_str}")
# Out:
# State          N counties R-squared     white     black  hispanic    female     <29YO     >65YO    hh_inc  unemploy       <hs  <college     rural
# Washington             39     0.776    -0.397     0.372   -0.0675     0.729     -0.39     0.398  0.000446      2.04    0.0344    -0.896   -0.0294
# Kansas                105      0.77    -0.597     0.481    -0.648     0.555    -0.541     -1.05 -0.000186     0.778     0.205    -0.556   -0.0539
# South Dakota           66      0.76    -0.326     0.979     0.607    -0.601     0.457     0.266  6.25e-05     0.237    0.0226    -0.397     -0.03
# Minnesota              87     0.757    -0.424     0.998     0.348     -1.09    -0.017     0.622 -0.000237     0.432     -1.39    -0.544   -0.0357
# Wisconsin              72     0.706    -0.313      0.43   -0.0349    -0.645    -0.383     -1.74 -0.000854    -0.585    -0.802    -0.809    0.0897
# West Virginia          55     0.696     -1.26     -1.11    -0.311     0.444   -0.0101     0.192 -2.23e-05    0.0694     0.202    -0.591   -0.0418
# Nebraska               93     0.695    -0.303      1.77    -0.732     0.283     0.234      0.25  0.000289     0.739     0.922   -0.0628   -0.0937
# North Dakota           53     0.683    -0.544    -0.833   -0.0479    -0.111     0.415      1.11 -0.000241      0.47     -1.33    -0.381    -0.062
# Kentucky              120     0.642    -0.063     0.483     0.239   -0.0246    -0.138    -0.303 -0.000122    -0.258    -0.354    -0.437   -0.0138
# Iowa                   99     0.598     -1.16     0.606     -1.21      1.55   -0.0946    -0.684 -2.33e-05     0.507    -0.539    0.0107   -0.0237

# %%
state = 'Texas'
subset = nation[nation['state'] == state]
y = subset['pctHC'] # dependent varible

x = subset[['white_pct', 'black_pct','hispanic_pct', 'female_pct',
        'age29andunder_pct', 'age65andolder_pct', 'median_hh_inc',
        'clf_unemploy_pct', 'lesshs_pct', 'lesscollege_pct',
            'rural_pct']]

x = sm.add_constant(x)

model = sm.OLS(y,x).fit()

#predictions = model.predict(x)

print(f"Results for {state}. N counties: {len(subset)}")
print(model.summary())
# Out:
# Results for Texas. N counties: 254
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  pctHC   R-squared:                       0.801
# Model:                            OLS   Adj. R-squared:                  0.792
# Method:                 Least Squares   F-statistic:                     88.76
# Date:                Sun, 19 Feb 2023   Prob (F-statistic):           2.15e-78
# Time:                        10:34:01   Log-Likelihood:                -857.86
# No. Observations:                 254   AIC:                             1740.
# Df Residuals:                     242   BIC:                             1782.
# Df Model:                          11
# Covariance Type:            nonrobust
# =====================================================================================
#                         coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------------
# const               137.1440     25.549      5.368      0.000      86.818     187.470
# white_pct            -0.8058      0.252     -3.198      0.002      -1.302      -0.309
# black_pct            -0.0536      0.278     -0.192      0.848      -0.602       0.495
# hispanic_pct         -0.1695      0.248     -0.682      0.496      -0.659       0.320
# female_pct            0.6007      0.168      3.572      0.000       0.269       0.932
# age29andunder_pct    -0.5012      0.157     -3.196      0.002      -0.810      -0.192
# age65andolder_pct    -0.4973      0.210     -2.367      0.019      -0.911      -0.084
# median_hh_inc        -0.0003   6.55e-05     -4.027      0.000      -0.000      -0.000
# clf_unemploy_pct      1.2946      0.198      6.524      0.000       0.904       1.685
# lesshs_pct           -0.0967      0.121     -0.797      0.426      -0.336       0.142
# lesscollege_pct      -0.6550      0.097     -6.777      0.000      -0.845      -0.465
# rural_pct            -0.0192      0.020     -0.945      0.346      -0.059       0.021
# ==============================================================================
# Omnibus:                        3.656   Durbin-Watson:                   1.782
# Prob(Omnibus):                  0.161   Jarque-Bera (JB):                4.381
# Skew:                           0.029   Prob(JB):                        0.112
# Kurtosis:                       3.641   Cond. No.                     2.77e+06
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 2.77e+06. This might indicate that there are
# strong multicollinearity or other numerical problems.

# %%
string = 'able was i ere i saw elba'
if string[::1] == string[::-1]:
    print ('palindrome')
else:
    print ('not palindrome')
# Out:
# palindrome
