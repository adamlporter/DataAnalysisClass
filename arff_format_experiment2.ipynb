# %%
import pandas as pd
from arff import load

with open('/home/aporter/Downloads/GoodreadsComputerBooks.arff') as f:
    data=load(f)

df = pd.DataFrame(data['data'], columns = [attr for attr in data['attributes']])

df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1234 entries, 0 to 1233
# Data columns (total 10 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   (Book_Id, INTEGER)       1234 non-null   int64
#  1   (book_Title, STRING)     1234 non-null   object
#  2   (Author_Name, STRING)    1234 non-null   object
#  3   (ratings_count, REAL)    1234 non-null   float64
#  4   (Avg_Rating, REAL)       1234 non-null   float64
#  5   (Publish_year, INTEGER)  1234 non-null   int64
#  6   (Edition, INTEGER)       1234 non-null   int64
#  7   (Pages_no, INTEGER)      1234 non-null   int64
#  8   (Book_language, STRING)  1234 non-null   object
#  9   (Reviews, INTEGER)       1234 non-null   int64
# dtypes: float64(2), int64(5), object(3)
# memory usage: 96.5+ KB

# %%
df.columns = [x[0] for x in df.columns]

# %%
df.sample(5)
# Out:
#       Book_Id                                         book_Title  \
# 260       261  Thought Contagion: When Ideas ACT Like Viruses...
# 159       159  Counter Hack Reloaded: A Step  By  Step Guide ...
# 175       175  Hacking: Ultimate Hacking for Beginners How to...
# 1051     1229  Power Reference Manual for the Electrical and ...
# 268       269  Cambridge IGCSE Computer Studies Coursebook [W...
#
#             Author_Name  ratings_count  Avg_Rating  Publish_year  Edition  \
# 260         Aaron Lynch          121.0        3.22          1996        4
# 159     Edward Skoudis           217.0        4.00          2005        4
# 175     Andrew McKinnon          131.0        3.47          2015        2
# 1051     John A. Camara           13.0        4.08          2010        2
# 268   Chris Leadbetter            47.0        4.38          2011        2
#
#       Pages_no Book_language  Reviews
# 260        208       English       10
# 159        748       English        4
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4028 entries, 0 to 4027
# Data columns (total 7 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   game_length  4028 non-null   object
#  1   mmr          0 non-null      object
#  2   result       4028 non-null   object
#  3   server       4028 non-null   object
#  4   team_1       4028 non-null   object
#  5   team_2       4028 non-null   object
#  6   timestamp    4028 non-null   object
# dtypes: object(7)
# memory usage: 220.4+ KB

# %%
df['Publish_year'].value_counts()
# Out:
# Publish_year
# 2015    67
# 2013    54
# 2010    46
# 2004    44
# 2014    44
# 2012    44
# 2009    42
# 2002    41
# 2011    39
# 2001    38
# 2000    38
# 2016    37
# 2008    37
# 2007    36
# 1998    34
# 2003    34
# 2018    32
# 1995    31
# 2017    30
# 2005    30
# 1996    30
# 1999    29
# 2019    29
# 2006    27
# 1997    25
# 2020    23
# 1993    22
# 1984    21
# 1990    19
# 1988    16
# 1987    16
# 1991    15
# 1994    15
# 1983    15
# 1992    15
# 1986    14
# 1985    13
# 1982    13
# 1989    11
# 1978     9
# 1981     7
# 1976     7
# 1972     5
# 1974     5
# 1975     5
# 1979     5
# 1980     5
# 1977     4
# 1973     3
# 1963     2
# 1969     2
# 2021     2
# 1960     2
# 1900     1
# 1970     1
# 1958     1
# 1971     1
# 1901     1
# Name: count, dtype: int64
